# %% [markdown]
# <h2> Fruit Shop </h2>

# %% [markdown]
# <pre>
# 5 fruits
# what fruit you want - Apple/aPPle/aPple or any version of apple (1 $)
# grapes/Grapes/GrapeS or any version of grapes - 1$
# any other fruit/anything - 50 cents
# min amt - 2.5$
# </pre>

# %%
#by Grant #here apples and apple are both considered different 
cost = 0
print "Fruit shop"
for i in range(5):
    fruit = raw_input('Pick a fruit to buy ')
    if fruit.lower() == 'apple':
        print "Bought 1 apple"
        cost = cost + 1
    elif fruit.lower() == 'grapes':
        print "Bought some grapes"
        cost = cost + 1
    else:
        print "Bought other fruit"
        cost = cost + 0.5
print "Your total cost was", cost
# Out:
# Fruit shop
# Pick a fruit to buy apple
# Bought 1 apple
# Pick a fruit to buy Apples
# Bought other fruit
# Pick a fruit to buy grapes
# Bought some grapes
# Pick a fruit to buy apple
# Bought 1 apple
# Pick a fruit to buy mango
# Bought other fruit
# Your total cost was 4.0

# %% [markdown]
# <h2> Dictionaries </h2>

# %%
first_dict = {'eshaan':'wrong website','amanda':'vice president'}

# %%
first_dict['eshaan'] #eshaan is a  key
# Out:
# 'wrong website'

# %%
first_dict['amanda'] #amanda is the key and vice president is value
# Out:
# 'vice president'

# %% [markdown]
# <h3> What do you think will happen here </h3>

# %%
first_dict['ethan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d7b573591c27> in <module>()
# ----> 1 first_dict['ethan']
#
# KeyError: 'ethan'

# %% [markdown]
# <h3> How to get around that </h3>

# %%
first_dict.get('ethan',0) #if key ethan is there get me the value else 0
# Out:
# 0

# %%
first_dict.get('amanda',0) #because amanda is there
# Out:
# 'vice president'

# %%
first_dict #orderless
# Out:
# {'amanda': 'vice president', 'eshaan': 'wrong website'}

# %% [markdown]
# <h3> Is this right </h3>

# %%
first_dict[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6684b8c2bf18> in <module>()
# ----> 1 first_dict[0]
#
# KeyError: 0

# %%
first_dict.get(0,'other')
# Out:
# 'other'

# %% [markdown]
# <h3> Some Useful functions </h3>

# %%
first_dict.keys()
# Out:
# ['eshaan', 'amanda']

# %%
first_dict.values()
# Out:
# ['wrong website', 'vice president']

# %%
first_dict.items()
# Out:
# [('eshaan', 'wrong website'), ('amanda', 'vice president')]

# %% [markdown]
# <h3> Fruit shop back </h3>

# %%
fruits_dict = {'apple':1,'grapes':1}

# %%
fruits_dict['apple']
# Out:
# 1

# %%
fruits_dict['grapes']
# Out:
# 1

# %%
fruits_dict['other']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-0bd0ea07a3fa> in <module>()
# ----> 1 fruits_dict['other']
#
# KeyError: 'other'

# %%
fruits_dict.get('other',0)
# Out:
# 0

# %%
fruits_dict = {'apple':1,'grapes':1}
cost = 0
print "Fruit shop"
for i in range(5):
    fruit = raw_input('Pick a fruit to buy ').lower()
    cost = cost + fruits_dict.get(fruit,0.5)
print "Your total cost was", cost
# Out:
# Fruit shop
# Pick a fruit to buy apple
# Pick a fruit to buy grapes
# Pick a fruit to buy kiwi
# Pick a fruit to buy grape
# Pick a fruit to buy mango
# Your total cost was 3.5

# %% [markdown]
# <h3> String substitution </h3>

# %%
value = "good"
another_value = 'great'
"vijendra is %s and %s"%(value,another_value)
# Out:
# 'vijendra is good and great'

# %%
"vijendra is %s and %s"%(value,value)
# Out:
# 'vijendra is good and good'

# %% [markdown]
# <h3>Another method - Use dictionary </h3>

# %%
value_dict = {'value':'grant','another_value':'Patrick'}
"%(value)s and %(another_value)s are friends"%value_dict
# Out:
# 'grant and Patrick are friends'

# %%
value_dict = {'value':'grant','another_value':'Patrick','special':'aidan' }
"%(special)s and %(special)s are friends"%value_dict
# Out:
# 'aidan and aidan are friends'

# %% [markdown]
# <h3> Some functions we learnt so far </h3>
# <pre>
# first_dict.get
# first_dict.items
# first_dict.keys
# first_dict.values
# </pre>

# %% [markdown]
# <h3> Do we have to remember them ----- Obviously not (dir and help function for help)</h3>

# %%
dir(first_dict)
# Out:
# ['__class__',
#  '__cmp__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'has_key',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'itervalues',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values',
#  'viewitems',
#  'viewkeys',
#  'viewvalues']

# %%
help(first_dict)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __contains__(...)
#  |      D.__contains__(k) -> True if D has a key k, else False
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
#  |      x.__le__(y) <==> x<=y
#  |
#  |  __len__(...)
#  |      x.__len__() <==> len(x)
#  |
#  |  __lt__(...)
#  |      x.__lt__(y) <==> x<y
#  |
#  |  __ne__(...)
#  |      x.__ne__(y) <==> x!=y
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(...)
#  |      dict.fromkeys(S[,v]) -> New dict with keys from S and values equal to v.
#  |      v defaults to None.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  has_key(...)
#  |      D.has_key(k) -> True if D has a key k, else False
#  |
#  |  items(...)
#  |      D.items() -> list of D's (key, value) pairs, as 2-tuples
#  |
#  |  iteritems(...)
#  |      D.iteritems() -> an iterator over the (key, value) items of D
#  |
#  |  iterkeys(...)
#  |      D.iterkeys() -> an iterator over the keys of D
#  |
#  |  itervalues(...)
#  |      D.itervalues() -> an iterator over the values of D
#  |
#  |  keys(...)
#  |      D.keys() -> list of D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E present and has a .keys() method, does:     for k in E: D[k] = E[k]
#  |      If E present and lacks .keys() method, does:     for (k, v) in E: D[k] = v
#  |      In either case, this is followed by: for k in F: D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> list of D's values
#  |
#  |  viewitems(...)
#  |      D.viewitems() -> a set-like object providing a view on D's items
#  |
#  |  viewkeys(...)
#  |      D.viewkeys() -> a set-like object providing a view on D's keys
#  |
#  |  viewvalues(...)
#  |      D.viewvalues() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T

# %%
name = "becca"

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_formatter_field_name_split',
#  '_formatter_parser',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
#can we do directly last and this result are same 
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_formatter_field_name_split',
#  '_formatter_parser',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
dir(int)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__class__',
#  '__cmp__',
#  '__coerce__',
#  '__delattr__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__hash__',
#  '__hex__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__long__',
#  '__lshift__',
#  '__mod__',
#  '__mul__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__oct__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'imag',
#  'numerator',
#  'real']

# %% [markdown]
# <h3>Make a random list of 1000 numbers and the random number should be between 1 -10 </h3>
# <pre>
# a = [1,3,5,9,4,3,1.....]
# You have to use
# random.randint
# append
# </pre>

# %%
#by Dylan
import random
num_list = []
x = 0
while x <= 1000:
    num = random.randint(1,10)
    num_list.append(num)
    x = x+1
print num_list
# Out:
# [3, 3, 3, 7, 7, 7, 8, 1, 3, 5, 2, 8, 8, 2, 6, 4, 1, 4, 8, 5, 1, 2, 2, 5, 10, 6, 10, 3, 4, 8, 4, 9, 2, 5, 1, 10, 7, 6, 3, 6, 6, 1, 10, 2, 9, 3, 8, 6, 8, 4, 2, 3, 3, 7, 5, 4, 8, 1, 8, 6, 7, 10, 3, 5, 4, 3, 10, 10, 9, 7, 9, 10, 7, 1, 1, 7, 8, 9, 4, 10, 7, 1, 10, 5, 6, 3, 10, 3, 7, 3, 2, 2, 2, 5, 3, 8, 4, 4, 1, 4, 8, 10, 6, 3, 6, 7, 10, 1, 8, 4, 9, 7, 3, 5, 1, 2, 4, 1, 8, 1, 9, 3, 3, 8, 3, 9, 6, 6, 3, 6, 3, 1, 8, 5, 7, 5, 2, 9, 2, 5, 9, 2, 4, 1, 3, 9, 8, 9, 5, 5, 4, 9, 7, 2, 3, 9, 6, 2, 4, 8, 6, 4, 8, 6, 2, 5, 3, 1, 10, 2, 5, 6, 1, 9, 1, 6, 4, 3, 5, 10, 4, 8, 1, 1, 7, 4, 10, 4, 9, 1, 8, 5, 9, 9, 7, 5, 4, 10, 4, 9, 6, 7, 5, 10, 5, 5, 6, 10, 9, 10, 6, 4, 5, 8, 5, 10, 5, 3, 9, 8, 2, 2, 8, 5, 4, 9, 1, 1, 2, 5, 2, 5, 9, 8, 7, 5, 6, 6, 8, 4, 8, 7, 8, 2, 5, 2, 7, 10, 6, 2, 6, 2, 10, 4, 1, 5, 4, 4, 9, 5, 2, 6, 7, 10, 8, 1, 3, 2, 5, 10, 5, 1, 10, 9, 8, 7, 3, 4, 4, 9, 1, 3, 2, 10, 10, 7, 10, 9, 10, 1, 2, 5, 10, 7, 10, 1, 4, 7, 10, 6, 8, 10, 7, 6, 3, 3, 6, 8, 10, 7, 1, 3, 7, 1, 2, 1, 3, 7, 7, 7, 7, 4, 8, 2, 9, 5, 5, 9, 10, 8, 3, 7, 3, 2, 5, 6, 5, 2, 10, 2, 4, 9, 5, 10, 2, 5, 3, 4, 1, 2, 6, 4, 2, 3, 5, 1, 2, 4, 3, 9, 6, 8, 4, 7, 3, 9, 10, 5, 6, 6, 10, 2, 6, 4, 7, 3, 2, 10, 6, 2, 7, 7, 9, 7, 7, 2, 3, 8, 10, 2, 10, 5, 9, 1, 5, 4, 7, 2, 10, 10, 10, 8, 5, 3, 10, 7, 8, 1, 9, 9, 9, 3, 8, 8, 4, 8, 9, 5, 8, 3, 4, 3, 9, 8, 10, 10, 5, 8, 2, 4, 9, 6, 6, 4, 3, 4, 2, 10, 6, 2, 3, 6, 6, 10, 9, 3, 6, 10, 1, 7, 2, 5, 2, 6, 6, 1, 2, 5, 1, 3, 7, 10, 8, 2, 9, 3, 4, 4, 4, 3, 2, 6, 9, 9, 10, 4, 7, 10, 6, 7, 7, 2, 1, 4, 3, 1, 5, 8, 7, 6, 9, 2, 3, 5, 2, 8, 9, 6, 10, 7, 9, 9, 6, 8, 8, 6, 1, 5, 9, 9, 3, 9, 8, 8, 4, 5, 4, 2, 5, 10, 9, 9, 8, 2, 2, 4, 5, 10, 10, 10, 9, 4, 3, 5, 6, 3, 5, 9, 10, 6, 6, 4, 9, 2, 9, 3, 2, 7, 3, 9, 4, 1, 10, 1, 7, 6, 1, 4, 7, 3, 1, 4, 6, 8, 9, 7, 8, 2, 1, 1, 6, 2, 2, 4, 4, 10, 1, 5, 8, 4, 1, 10, 7, 5, 8, 8, 10, 3, 6, 6, 9, 4, 2, 2, 7, 5, 2, 8, 4, 6, 6, 5, 8, 4, 3, 6, 9, 2, 7, 6, 10, 10, 5, 5, 3, 10, 3, 7, 7, 6, 5, 1, 3, 7, 4, 4, 3, 1, 8, 5, 6, 10, 7, 10, 9, 7, 5, 4, 7, 2, 2, 6, 1, 3, 1, 8, 7, 5, 1, 5, 2, 5, 1, 5, 3, 6, 1, 9, 1, 3, 8, 4, 4, 10, 6, 10, 6, 9, 3, 7, 8, 5, 9, 2, 3, 3, 2, 3, 7, 6, 5, 8, 3, 1, 4, 2, 7, 4, 10, 6, 4, 6, 9, 10, 7, 4, 10, 9, 10, 1, 10, 1, 8, 3, 4, 5, 2, 9, 3, 9, 5, 10, 3, 10, 5, 6, 5, 7, 1, 1, 6, 2, 5, 3, 4, 1, 5, 3, 5, 7, 10, 7, 7, 4, 3, 1, 4, 6, 10, 8, 9, 4, 3, 4, 8, 4, 5, 4, 9, 8, 1, 1, 6, 10, 9, 10, 7, 5, 10, 5, 3, 2, 8, 6, 6, 6, 8, 3, 8, 6, 6, 8, 8, 10, 10, 4, 8, 3, 1, 7, 2, 4, 3, 1, 7, 10, 2, 5, 1, 5, 7, 5, 5, 3, 10, 9, 8, 8, 8, 1, 3, 7, 7, 6, 9, 6, 8, 9, 6, 7, 7, 2, 1, 10, 6, 3, 5, 8, 1, 9, 6, 6, 1, 6, 4, 9, 7, 2, 2, 4, 3, 4, 4, 3, 1, 6, 10, 1, 8, 10, 9, 2, 8, 8, 3, 3, 9, 8, 5, 10, 4, 7, 10, 9, 10, 10, 6, 5, 4, 6, 9, 4, 2, 6, 8, 10, 5, 10, 7, 2, 7, 5, 4, 1, 5, 10, 3, 9, 1, 6, 6, 5, 9, 4, 3, 5, 3, 7, 3, 3, 10, 4, 7, 3, 1, 10, 8, 3, 9, 4, 1, 4, 2, 10, 4, 4, 3, 8, 6, 9, 5, 6, 2, 9, 4, 10, 7, 6, 8, 4, 9, 1, 5, 5, 8, 9, 5, 7, 5, 8, 2, 1, 8, 1, 7, 10, 5, 1, 3, 10, 1, 3, 4, 8, 6, 4, 2, 1, 1, 1, 8, 3, 5, 5, 5, 2, 3, 1, 4, 5, 6, 6, 4, 2, 8, 8, 4, 6, 3, 3, 1, 3, 8, 3, 1, 6, 10, 3, 10, 6, 9, 4, 3, 5, 5, 2, 6, 5, 10, 1, 6, 10, 1, 6, 2, 9, 5, 10, 6, 1, 7]

# %%
#by Eshaan
import random
x=[]
for i in range(1,1001):
    num=random.randint(1,10)
    x.append(num)
print x
# Out:
# [8, 1, 6, 6, 10, 3, 7, 4, 3, 9, 2, 10, 10, 7, 9, 5, 9, 9, 4, 4, 3, 5, 5, 7, 8, 8, 2, 4, 5, 1, 1, 3, 7, 6, 6, 3, 2, 7, 7, 3, 5, 10, 10, 9, 4, 5, 1, 7, 6, 5, 8, 3, 8, 3, 7, 6, 4, 7, 9, 7, 3, 10, 4, 9, 5, 8, 6, 9, 8, 3, 6, 2, 8, 7, 6, 7, 7, 8, 3, 4, 4, 4, 10, 9, 3, 7, 9, 9, 8, 1, 10, 5, 9, 6, 6, 1, 7, 7, 6, 9, 6, 7, 9, 10, 3, 6, 9, 6, 7, 1, 6, 4, 9, 6, 8, 5, 9, 4, 9, 2, 8, 10, 6, 2, 8, 3, 4, 10, 1, 3, 4, 7, 2, 8, 10, 9, 3, 5, 2, 4, 7, 6, 8, 4, 1, 2, 5, 5, 6, 5, 2, 9, 6, 1, 2, 4, 9, 3, 8, 9, 4, 1, 3, 9, 2, 6, 1, 8, 3, 8, 5, 7, 7, 6, 3, 2, 7, 5, 6, 2, 7, 7, 5, 5, 8, 3, 1, 9, 8, 9, 5, 2, 2, 2, 8, 3, 5, 7, 1, 8, 7, 1, 1, 8, 9, 1, 3, 10, 6, 4, 4, 5, 5, 8, 10, 1, 4, 5, 3, 9, 7, 4, 7, 9, 6, 9, 3, 6, 1, 2, 8, 8, 7, 6, 10, 6, 5, 9, 2, 5, 4, 8, 4, 3, 8, 2, 5, 3, 10, 2, 2, 7, 2, 10, 1, 3, 8, 2, 2, 9, 4, 2, 5, 1, 9, 8, 8, 4, 6, 4, 10, 10, 6, 1, 3, 3, 6, 3, 4, 2, 7, 4, 2, 2, 7, 9, 3, 9, 7, 4, 9, 2, 7, 7, 6, 8, 8, 2, 3, 1, 5, 6, 10, 10, 5, 1, 9, 5, 4, 2, 4, 1, 4, 8, 9, 6, 1, 7, 4, 9, 8, 7, 9, 8, 5, 7, 2, 2, 3, 7, 9, 3, 10, 10, 5, 2, 8, 10, 8, 4, 9, 7, 3, 8, 8, 10, 2, 3, 10, 9, 6, 7, 1, 8, 1, 7, 6, 10, 2, 1, 1, 3, 9, 10, 1, 5, 8, 9, 10, 5, 10, 8, 7, 3, 7, 6, 5, 6, 9, 1, 2, 3, 4, 5, 4, 2, 2, 10, 7, 2, 3, 10, 6, 2, 1, 4, 5, 4, 9, 3, 8, 7, 3, 10, 9, 8, 10, 2, 5, 7, 10, 1, 2, 6, 7, 3, 10, 2, 9, 9, 7, 10, 3, 7, 10, 5, 6, 7, 5, 8, 4, 2, 9, 4, 5, 3, 10, 9, 8, 5, 10, 8, 8, 2, 1, 7, 2, 2, 10, 5, 10, 5, 9, 5, 8, 10, 6, 6, 4, 3, 8, 4, 10, 4, 7, 3, 3, 8, 7, 10, 8, 7, 4, 2, 8, 8, 7, 5, 6, 5, 2, 2, 9, 1, 8, 2, 1, 2, 1, 1, 6, 4, 9, 5, 6, 3, 5, 10, 9, 4, 3, 2, 10, 9, 2, 5, 4, 10, 4, 10, 5, 4, 7, 9, 1, 1, 6, 2, 9, 8, 5, 9, 1, 9, 4, 2, 4, 3, 4, 10, 1, 1, 1, 2, 3, 3, 4, 8, 2, 6, 3, 8, 9, 7, 10, 4, 4, 8, 9, 1, 3, 2, 3, 8, 8, 8, 4, 6, 9, 2, 8, 5, 3, 5, 5, 7, 2, 2, 5, 2, 2, 3, 5, 5, 8, 2, 2, 6, 1, 9, 6, 6, 7, 5, 4, 5, 3, 9, 4, 8, 5, 6, 2, 6, 6, 7, 9, 8, 4, 4, 7, 10, 10, 4, 3, 2, 10, 3, 7, 6, 9, 5, 3, 10, 7, 8, 4, 4, 2, 9, 6, 10, 10, 1, 4, 6, 5, 7, 9, 7, 7, 6, 5, 8, 1, 4, 7, 10, 7, 5, 5, 6, 9, 10, 6, 1, 10, 10, 7, 10, 1, 10, 8, 1, 10, 3, 7, 4, 2, 8, 2, 8, 2, 2, 4, 6, 9, 2, 5, 1, 2, 9, 9, 1, 7, 10, 8, 2, 7, 2, 4, 5, 2, 3, 3, 5, 8, 3, 8, 1, 2, 7, 5, 7, 7, 3, 7, 1, 6, 7, 4, 7, 9, 8, 3, 5, 7, 6, 6, 10, 10, 6, 2, 1, 2, 3, 9, 9, 1, 10, 10, 1, 4, 9, 9, 2, 6, 2, 4, 3, 7, 10, 6, 9, 1, 3, 4, 2, 5, 1, 2, 6, 9, 5, 5, 10, 1, 3, 3, 10, 8, 7, 4, 8, 9, 5, 3, 2, 3, 3, 2, 8, 3, 5, 9, 7, 10, 4, 6, 4, 8, 4, 7, 4, 10, 4, 1, 2, 3, 4, 1, 1, 2, 2, 4, 4, 1, 3, 6, 8, 2, 9, 10, 4, 2, 9, 4, 5, 6, 2, 6, 7, 7, 8, 3, 5, 4, 10, 10, 5, 6, 4, 8, 5, 3, 1, 4, 4, 5, 7, 5, 7, 8, 9, 6, 8, 4, 6, 10, 9, 2, 8, 7, 5, 5, 7, 6, 6, 5, 8, 10, 3, 1, 6, 9, 3, 7, 10, 6, 8, 10, 7, 10, 9, 9, 9, 10, 1, 4, 6, 10, 3, 1, 5, 3, 8, 4, 4, 3, 3, 4, 8, 9, 4, 1, 2, 6, 7, 2, 7, 8, 8, 4, 7, 7, 4, 5, 6, 4, 5, 7, 10, 8, 7, 6, 10, 8, 10, 3, 9, 7, 8, 10, 3, 7, 6, 6, 5, 7, 1, 9, 6, 2, 10, 8, 10, 6, 1, 5, 7, 4, 10, 1, 9, 4, 6, 10, 6, 9, 3, 5, 5, 6, 3, 1, 8, 2, 6, 10, 7, 3, 3, 6, 9, 7, 9, 8, 6, 7, 8, 2, 2, 7, 5, 3, 1, 9, 6, 8, 8, 3, 9, 8, 5, 10, 9, 1, 2, 2, 5, 10, 1, 1, 10, 4, 6, 1, 6, 6, 5, 3, 7, 10, 10, 3, 5, 2, 10, 1, 1, 3, 7, 5, 6, 9, 9, 6, 8, 2, 4]

# %% [markdown]
# <h3> Single line - list comprehension Pythonic way </h3>

# %%
#by Aidan
import random
num_list = [random.randint(1, 10) for i in range(1000)]
print num_list
# Out:
# [3, 2, 3, 7, 6, 3, 7, 5, 10, 3, 4, 10, 6, 10, 7, 7, 4, 9, 1, 10, 4, 3, 4, 2, 5, 3, 1, 7, 3, 2, 2, 9, 5, 3, 2, 5, 7, 2, 3, 9, 5, 5, 1, 5, 5, 6, 3, 10, 6, 10, 4, 4, 6, 8, 1, 7, 4, 7, 3, 2, 6, 8, 6, 5, 7, 4, 8, 5, 6, 3, 9, 9, 8, 5, 6, 10, 9, 4, 3, 2, 5, 5, 1, 8, 8, 10, 1, 2, 4, 5, 9, 1, 1, 4, 3, 10, 7, 6, 6, 1, 9, 4, 2, 6, 10, 4, 2, 3, 9, 10, 8, 2, 8, 3, 7, 10, 7, 10, 1, 1, 5, 5, 2, 9, 10, 7, 5, 4, 5, 2, 9, 4, 4, 5, 8, 8, 1, 9, 4, 7, 1, 6, 7, 8, 6, 5, 3, 6, 9, 9, 3, 7, 1, 7, 6, 9, 6, 6, 6, 6, 2, 6, 10, 6, 6, 1, 6, 3, 6, 7, 5, 1, 5, 6, 2, 8, 2, 1, 2, 1, 9, 4, 3, 7, 1, 1, 9, 6, 1, 9, 4, 10, 2, 2, 8, 7, 10, 6, 5, 9, 3, 3, 6, 5, 5, 9, 5, 6, 3, 10, 7, 1, 5, 4, 2, 6, 9, 4, 10, 6, 10, 1, 7, 5, 3, 3, 6, 7, 7, 6, 10, 7, 2, 5, 3, 8, 6, 5, 7, 10, 10, 5, 6, 3, 8, 7, 4, 4, 1, 10, 10, 4, 1, 7, 3, 10, 6, 1, 5, 8, 4, 6, 2, 3, 5, 5, 6, 3, 8, 8, 7, 8, 9, 5, 2, 1, 8, 4, 8, 4, 1, 1, 2, 1, 10, 1, 1, 4, 9, 8, 2, 1, 9, 6, 10, 1, 9, 5, 7, 2, 1, 6, 10, 5, 2, 10, 10, 8, 3, 6, 6, 2, 9, 5, 5, 4, 5, 1, 10, 9, 5, 2, 3, 1, 9, 10, 1, 1, 1, 6, 1, 4, 3, 6, 8, 10, 10, 3, 10, 7, 10, 7, 2, 2, 9, 2, 3, 8, 4, 2, 4, 1, 8, 3, 7, 3, 6, 9, 9, 3, 1, 7, 5, 2, 3, 9, 1, 2, 9, 10, 4, 2, 9, 3, 8, 3, 6, 7, 2, 1, 1, 3, 2, 8, 6, 6, 6, 1, 9, 5, 3, 10, 6, 1, 5, 6, 10, 2, 3, 10, 4, 4, 6, 10, 2, 10, 2, 7, 3, 6, 2, 7, 5, 10, 2, 10, 2, 2, 4, 2, 10, 7, 3, 9, 5, 1, 1, 5, 3, 8, 10, 9, 4, 10, 4, 1, 1, 4, 9, 8, 1, 1, 7, 8, 3, 8, 7, 2, 10, 8, 2, 3, 5, 3, 8, 2, 5, 10, 1, 5, 3, 6, 4, 4, 4, 2, 6, 3, 6, 4, 6, 3, 6, 9, 4, 5, 7, 4, 7, 3, 3, 5, 5, 2, 5, 9, 3, 8, 7, 5, 10, 7, 1, 5, 2, 4, 1, 8, 3, 7, 1, 7, 8, 3, 7, 9, 6, 7, 6, 6, 8, 3, 5, 3, 1, 2, 1, 9, 2, 10, 2, 1, 9, 2, 9, 3, 8, 3, 5, 8, 6, 6, 7, 8, 2, 8, 8, 3, 4, 4, 3, 3, 10, 7, 4, 9, 8, 10, 5, 6, 2, 4, 2, 3, 10, 6, 9, 9, 1, 10, 3, 6, 9, 8, 3, 8, 8, 8, 8, 5, 9, 3, 6, 3, 2, 2, 9, 3, 4, 7, 7, 4, 6, 8, 4, 8, 7, 2, 10, 9, 7, 6, 6, 3, 6, 2, 1, 7, 4, 2, 2, 9, 4, 3, 5, 3, 1, 6, 1, 1, 10, 6, 5, 7, 6, 6, 7, 8, 10, 10, 4, 3, 4, 5, 6, 2, 5, 1, 10, 6, 4, 10, 8, 4, 1, 2, 1, 3, 10, 3, 4, 3, 10, 1, 9, 3, 5, 2, 5, 10, 8, 5, 2, 10, 4, 1, 8, 5, 4, 6, 6, 2, 5, 3, 2, 4, 6, 4, 8, 5, 3, 9, 5, 2, 10, 3, 8, 4, 3, 10, 1, 8, 8, 3, 2, 8, 2, 5, 5, 9, 1, 2, 5, 6, 4, 2, 9, 2, 7, 4, 1, 5, 2, 9, 3, 10, 6, 9, 5, 2, 3, 1, 8, 9, 4, 6, 5, 8, 10, 9, 7, 3, 8, 7, 1, 7, 2, 9, 3, 9, 1, 5, 5, 7, 7, 2, 1, 3, 10, 6, 5, 1, 6, 4, 3, 7, 5, 8, 7, 3, 4, 3, 8, 5, 3, 5, 4, 5, 4, 10, 8, 6, 7, 6, 2, 4, 9, 6, 9, 2, 8, 4, 4, 10, 3, 5, 3, 7, 3, 4, 10, 6, 7, 3, 6, 6, 10, 6, 6, 5, 7, 7, 8, 2, 8, 6, 1, 4, 7, 8, 8, 3, 10, 3, 10, 3, 3, 6, 6, 10, 8, 3, 7, 1, 7, 4, 7, 9, 5, 7, 3, 9, 5, 6, 7, 3, 9, 9, 5, 7, 7, 8, 3, 2, 6, 3, 1, 1, 10, 8, 6, 8, 1, 10, 1, 6, 1, 3, 5, 9, 2, 8, 1, 3, 1, 3, 5, 8, 10, 2, 9, 5, 5, 8, 4, 9, 6, 8, 9, 7, 9, 8, 7, 5, 4, 2, 2, 7, 3, 9, 2, 6, 9, 1, 5, 4, 6, 3, 4, 10, 10, 1, 1, 9, 5, 9, 4, 6, 2, 7, 2, 10, 6, 8, 9, 2, 2, 10, 2, 3, 5, 5, 1, 7, 9, 6, 1, 1, 3, 1, 7, 2, 2, 5, 5, 8, 8, 10, 2, 10, 1, 8, 6, 3, 1, 6, 6, 5, 5, 7, 3, 9, 9, 3, 1, 7, 8, 10, 4, 8, 9, 5, 6, 9, 4, 9, 5, 7, 3, 4, 7, 9, 6, 9, 1, 1, 4, 7, 9, 10, 4, 6, 2, 4, 6, 3, 9, 2, 3, 7, 8, 10, 4, 5, 10, 10, 3, 7, 3, 10, 7, 5, 4, 5, 1, 4, 1, 1, 9, 5]

# %% [markdown]
# <h3> Number of 4s </h3>

# %%
count =0
for i in num_list:
    if i ==4:
        count = count + 1
print count
# Out:
# 92

# %% [markdown]
# <h3> A little aside -Put values inside a dictionary </h3>

# %%
fruit_dict = {'apple':1,'grapes':1}

# %%
fruit_dict
# Out:
# {'apple': 1, 'grapes': 1}

# %%
fruit_dict['mango'] = 2 #key and value

# %%
fruit_dict
# Out:
# {'apple': 1, 'grapes': 1, 'mango': 2}

# %%
fruit_dict['blue-berries'] = 3

# %%
fruit_dict
# Out:
# {'apple': 1, 'blue-berries': 3, 'grapes': 1, 'mango': 2}

# %%
fruit_dict.items()
# Out:
# [('mango', 2), ('apple', 1), ('grapes', 1), ('blue-berries', 3)]

# %%
import random
num_list = [random.randint(1, 10) for i in range(1000)]

# %% [markdown]
# <h2> Find the count of each value in the list  </h2>
# <pre>
# you have to use dictionary
# {key(1/2/3/...):count}
# use get function here
# start with an empty dictionary
# </pre>
# <h3> Anyone wish to try counting with hand </h3>

# %%
num_count_dict = {}
import random
num_list = [random.randint(1, 10) for i in range(1000)]
for i in num_list:
    num_count_dict[i] = num_count_dict.get(i,0)  + 1
print num_count_dict.items()
# Out:
# [(1, 103), (2, 99), (3, 106), (4, 99), (5, 101), (6, 110), (7, 104), (8, 91), (9, 96), (10, 91)]

# %% [markdown]
# <h2> Now to Shakespeare- complete work by shakespeare Courtesy Gutenberg project</h2>
# <a href = "http://www.gutenberg.org/ebooks/100">click for more detail </a>

# %%
txt = open('Shakespeare.txt')
#i am changing all the words to lower so that 'The' is same as 'the'
words_shakespeare_list = txt.read().lower().split()

# %%
words_shakespeare_list[:10]  #first few words in the list
# Out:
# ['\xef\xbb\xbfthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william']

# %%
shakespeare_count_dict = {}
for i in words_shakespeare_list:
    shakespeare_count_dict[i] = shakespeare_count_dict.get(i,0)  + 1
print shakespeare_count_dict.items()
# Out:
# [('fawn', 11), ('considered,', 2), ('considered.', 3), ('mustachio', 1), ('protested,', 1), ('woods', 8), ('sending.', 3), ('hanging', 27), ('offendeth', 1), ('instant;', 1), ('beadsmen', 1), ('gad', 1), ('whither,', 7), ('whither.', 2), ('scold', 4), ('nunnery', 1), ('opener', 1), ('mutinies', 3), ('dance?', 4), ('whither?', 8), ('rests-that', 1), ('out-night', 1), ('benvolio', 4), ('sea-sorrow.', 1), ('wood!', 1), ('goodman,', 1), ('slothful', 1), ('spider.', 1), ("franklin's", 1), ('spider,', 4), ('wood,', 13), ('chambermaids.', 1), ('wood.', 8), ("suck'd.", 1), ('appropriation', 1), ("imagin'd", 7), ('wood;', 5), ('bringing', 17), ('fetter:', 1), ("cropp'd", 5), ('wooden', 8), ('ha!-hey', 1), ('seven?', 1), ('wednesday', 14), ('further:', 1), ('laments,', 2), ('belied;', 1), ('seven.', 2), ('seven,', 4), ('sooty', 1), ("tom's", 5), ('overswear;', 1), ('undeaf', 1), ('sooth', 2), ('sustaining', 2), ('consenting', 3), ('chin,', 4), ('chin.', 6), ("'hereafter'", 1), ('errors', 11), ('rhodes.', 1), ('nature!', 6), ('rhodes,', 4), ('nature,', 71), ('cyprus', 10), ('nature.', 32), ('indignity.', 5), ('circumference.', 2), ('unprovide', 1), ("madman's", 4), ('accessed,', 1), ('razeth', 1), ('nature?', 3), ('skill.--good', 1), ('nature:', 1), ('nature;', 10), ('titles;', 1), ('crouch', 3), ('chins', 2), ("flap-ear'd", 1), ('siward', 2), ('meteors,', 1), ('wrest,', 1), ('chine', 1), ('complainer,', 1), ('titles,', 5), ('titles.', 1), ("sluic'd", 2), ('boblibindo', 1), ('letters-this', 1), ('clapper-de-claw', 1), ('error:', 1), ('climbed', 1), ('tooth,', 3), ('controversy', 5), ('grecians?', 1), ('xiv.', 1), ('natures', 14), ('stock,', 8), ('error,', 7), ('error.', 4), ('ycleped', 1), ('circumstance,', 7), ('golden', 90), ('circumstance.', 5), ('projection', 1), ('athenian.', 13), ('him-no', 1), ('popular?', 1), ('lengthen', 2), ('circumstance?', 2), ('circumstance:', 1), ('stern', 25), ('unearned', 1), ('befits,', 1), ('speeches,', 4), ('homespuns', 1), ('studded', 1), ('oft;', 2), ('ascii,', 2), ('sternest', 1), ('ascii.', 1), ('extremity;', 1), ('footman?', 1), ('jerusalem;', 2), ('vicegerent', 1), ('leading,', 1), ('ascii"', 2), ('music', 96), ('therefore', 459), ('oft-', 1), ('oft,', 11), ('swoopstake', 1), ('sermons', 1), ('praiseworthy.', 1), ('russet-pated', 1), ("t'envelop", 1), ('homily', 1), ('pregnantly', 1), ('upbraidings', 1), ('unpack', 1), ('cobbler,', 1), ('circumstances', 6), ("captain's", 6), ('locked', 1), ('degrees;', 1), ('catch:', 1), ('liability,', 3), ('degrees?', 1), ('familiarity-', 1), ('catch,', 4), ('turtle-doves', 1), ('degrees.', 3), ('rocks.', 2), ('wand', 1), ('wane', 1), ('unjust', 13), ('reignier', 8), ('slavery.', 1), ('kingdoms', 21), ('want', 115), ("by'r", 17), ('footed;', 1), ('cookery', 1), ("by't", 1), ('absolute', 28), ('well-armed', 1), ('rites?', 1), ('rites:', 2), ("spurn'd", 1), ('travel', 21), ('copious', 1), ('rites,', 1), ('rites.', 2), ('shunning', 1), ('bowls.', 1), ('canaries', 1), ('cadence', 1), ("o'er-snowed", 1), ('oceans', 1), ('show:', 1), ('arch-villain', 1), ('chameleon,', 1), ('saintlike', 1), ('halloing', 2), ("greatness,'-", 1), ('wrong', 116), ('scornfully.', 1), ('chameleon.', 1), ("engag'd", 9), ('pint,', 1), ('unshunnable,', 1), ('decorum.', 1), ('wan?', 1), ('4,', 1), ('[kills', 1), ('clew;', 1), ("death-mark'd", 1), ('retired,', 1), ('reported?', 1), ('whore?', 4), ('misgives', 2), ('wiltshire?', 1), ('prophesier.', 1), ('effect!', 2), ('effect.', 8), ('effect,', 9), ('rudder.', 1), ('halfpence.', 1), ('[calling]', 1), ('whizzing', 1), ('damnable,', 1), ('summer-swelling', 1), ('sharply.', 1), ('sharply,', 2), ('bald,', 3), ("tam'd", 4), ('damnable.', 3), ('ostent,', 1), ('effect;', 4), ('welcomer', 1), ('welcomes', 2), ('grunt,', 1), ('wetting;', 1), ('flower.', 7), ('fit', 132), ('fix', 4), ('mayst', 62), ("deform'd.", 1), ("deform'd,", 1), ('worms.', 2), ('rescued', 4), ('worms,', 5), ('metres,', 1), ('fig', 3), ('fie', 30), ('wales', 15), ('malignant,', 1), ( ...

# %%
len(words_shakespeare_list)  #it is a lot 900 thousand
# Out:
# 904061

# %%
shakespeare_count_dict['the']  #the count of 'the'
# Out:
# 27729

# %%
shakespeare_count_dict['i']
# Out:
# 19540

# %%
shakespeare_count_dict['thou']
# Out:
# 5138

# %%
shakespeare_count_dict['words']
# Out:
# 219

# %%
shakespeare_count_dict['dust']
# Out:
# 29

# %%
shakespeare_count_dict['Joseph'] #he has not used it
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-76e55b4c3d0b> in <module>()
# ----> 1 shakespeare_count_dict['Joseph']
#
# KeyError: 'Joseph'

# %%
shakespeare_count_list =shakespeare_count_dict.items()

# %% [markdown]
# <h3> Puctuations deletetion - pending.... do it when you get time </h3>

# %% [markdown]
# <h3> Find the word that has maximum count </h3>

# %%
max(shakespeare_count_list,key = lambda x:x[1])
# Out:
# ('the', 27729)

# %% [markdown]
# <h3> Now that was intimidating </h3>
# <pre>
# lets see what we need to know before this
# we will come back
# </pre>

# %% [markdown]
# <h2> Functions most important </h2>

# %%
max([1,2,3,4,10]) #inbuilt function
# Out:
# 10

# %%
sorted([1,-1,2,-4,5])
# Out:
# [-4, -1, 1, 2, 5]

# %% [markdown]
# <h3> Functions are used </h3>
# <pre>
# 1. Writing code only once and using it over and over again
# 2. Functions allow us to test small part of program in isolation to another.
# 3. Can be a black box to the other programs - sometimes implementation details not important
# </pre>

# %%
# how do we write this
def max_printing(a):
    print "maximum of",a,max(a)

# %%
max_printing([1,4,4,6,10])
# Out:
# maximum of [1, 4, 4, 6, 10] 10

# %%
max_printing('vijendra')
# Out:
# maximum of vijendra v

# %%
max_printing([1,-1,-2,5,6])
# Out:
# maximum of [1, -1, -2, 5, 6] 6

# %% [markdown]
# <h3> Let's do your first function </h3>
# <pre>
# m ** n
# power(3,2)
# </pre>

# %%
def power(m,n):          #here m and n are called parameters
    return m**n

# %%
print "the value of ",2,'^',3,'=',power(2,3)     #function calling and 2,3 are arguments
# Out:
# the value of  2 ^ 3 = 8

# %% [markdown]
# <h3> Scrambled word function that will take 'vijendra' it will give a scrambled word </h3>

# %%
#this we used a lot yesterday
#copy yesterday's code and put it inside a function
def scramble(word):
    import random
    scrambled_word = list(word)
    random.shuffle(scrambled_word)
    scrambled_word = ''.join(scrambled_word)
    return scrambled_word #return statement

# %%
s = 'Dylan'

# %%
s=scramble(s)

# %%
s
# Out:
# 'ylanD'

# %%
#print the string 10 times
def print_string(s):
    for i in range(10):
        print s

# %%
print_string('ethan')
# Out:
# ethan
# ethan
# ethan
# ethan
# ethan
# ethan
# ethan
# ethan
# ethan
# ethan

# %% [markdown]
# <h3>Another problem- Table of a number</h3>
# <pre>
# table(n)- table of a number
# </pre>

# %%
#by Patrick
def table_of_number(n):
    for i in range(1,11):
        print n,'x',i,'=', n * i

# %%
table_of_number(10)
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# <h3> Prime numbers between 2 numbers </h3>
# <pre>
# prime(15,43)   - list all the prime numbers between 15 and 43 both 15 and 43 included
# </pre>

# %%
# by Becca explained very nicely by Dustin
def prime_numbers_between(m,n) :
    import math
    prime_number_list = []
    for i in range(m,n+1):
        #technically it make sense to check from 2 to only till sqrt of the number for prime
        #math magic computationaly more efficient less steps
        for j in range(2,int(math.sqrt(i)) + 1) :
            if i % j == 0  :
                  break
        else:       #this else is executed if the loop does not break
            prime_number_list.append(i) 
    return prime_number_list

# %%
prime_numbers_between(2,19)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %% [markdown]
# <h3> A side note </h3>

# %%
range(10.5) #this is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-464633192c01> in <module>()
# ----> 1 range(10.5) #this is not possible
#
# TypeError: range() integer end argument expected, got float.

# %% [markdown]
# <h3>Make a function which will add s to a string</h3>
# <pre>
# plural('cat')
# </pre>

# %%
#by Joseph
def plural(word):
    print word+"s"
    #no return statement here 
    #So None type

# %%
plural("cactu")
# Out:
# cactus

# %% [markdown]
# <h3> Why this none is printing in this case</h3>

# %%
print plural('cactus')  #because the plural function not returning anything so None
# Out:
# cactuss
# None

# %%
def plural_again(s):
    return s + 's'

# %%
print plural_again('dog') #no None this time
# Out:
# dogs

# %% [markdown]
# <h3> Key in functions - Pythonic </h3>

# %%
max([1,3,5,7])
# Out:
# 7

# %%
max([-1,-2,-5,-7])
# Out:
# -1

# %% [markdown]
# <h3> What is the answer - any guesses </h3>

# %%
max([-1,-2,-5,-7],key = abs)
#abs will give us distance from 0 and the max distance from 0 is of -7
# Out:
# -7

# %% [markdown]
# <h3> Square function </h3>

# %%
def square(x):
    return x*x

# %% [markdown]
# <h3> Can we use our own function in key -sure </h3>

# %%
max([-1,-2,-5,-7],key = square)
# Out:
# -7

# %%
max([-0.5,0.9,0.1,-0.95],key = square)
# Out:
# -0.95

# %%
#what is wrong - you cannot do sqrt of a -ve number
import math
max([-0.5,0.6,0.1],key = math.sqrt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-62e4e919bc54> in <module>()
#       1 import math
# ----> 2 max([-0.5,0.6,0.1],key = math.sqrt)
#
# ValueError: math domain error

# %% [markdown]
# <h3> Sorted function </h3>

# %%
sorted([4,1,8,7,6])
# Out:
# [1, 4, 6, 7, 8]

# %%
sorted([4,1,8,7,6],reverse = True) # reverse make it descending
# Out:
# [8, 7, 6, 4, 1]

# %% [markdown]
# <h3> How about this ?? </h3>

# %%
sorted([-4,-1,8,7,6],key = abs )
# Out:
# [-1, -4, 6, 7, 8]

# %%
#you cannot do operation like that there is a work around on this 
sorted([-4,-1,8,7,6],key = -1*abs )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-939ef675c974> in <module>()
# ----> 1 sorted([-4,-1,8,7,6],key = -1*abs )
#
# TypeError: unsupported operand type(s) for *: 'int' and 'builtin_function_or_method'

# %%
sorted([-12,-1,8,7,6],key = square)
# Out:
# [-1, 6, 7, 8, -12]

# %% [markdown]
# <h3> How about sorting a list of tuples </h3>

# %%
#sorting based on the first number of tuple that's automatic
sorted([(1,2),(3,1),(-1,3),(0,1)])
# Out:
# [(-1, 3), (0, 1), (1, 2), (3, 1)]

# %% [markdown]
# <h3> How many think we can sort based on 2nd number of tuple -sure we can </h3>

# %% [markdown]
# <h3> Key at rescue </h3>

# %%
def second_number(x):
    #this gets me the second element of the tuple
    return x[1]

# %%
sorted([(1,2),(3,1),(-1,3),(0,1)],key = second_number)
# Out:
# [(3, 1), (0, 1), (1, 2), (-1, 3)]

# %% [markdown]
# <h3> Again the single line philosophy Pythonic </h3>

# %%
#same result
sorted([(1,2),(3,1),(-1,3),(0,1)],key = lambda x:x[1])
# Out:
# [(3, 1), (0, 1), (1, 2), (-1, 3)]

# %%
def square(x):
    return x*x

# %%
square(5)
# Out:
# 25

# %% [markdown]
# <h3> Another way to define function </h3>

# %%
sq = lambda x:x*x

# %%
sq(5)
# Out:
# 25

# %% [markdown]
# <h3> Lambda itself is anonymous see below no name given to it </h3>
# <pre>
# Has to be a single line expression
# <a href ="https://docs.python.org/2/tutorial/controlflow.html#lambda-expressions">more information click here for python documentation </a>
# </pre>

# %%
# x is input here and x[1] is output or return type
sorted([(1,2),(3,1),(-1,3),(0,1)],key = lambda x:x[1])
# Out:
# [(3, 1), (0, 1), (1, 2), (-1, 3)]

# %%
max([(1,2),(3,1),(-1,3),(0,1)],key = lambda x:x[1])
# Out:
# (-1, 3)

# %%
min([(1,2),(3,1),(-1,3),(0,1)],key = lambda x:x[1])
# Out:
# (3, 1)

# %% [markdown]
# <h2>Shakespeare Revisited</h2>

# %%
shakespeare_count_list
# Out:
# [('fawn', 11),
#  ('considered,', 2),
#  ('considered.', 3),
#  ('mustachio', 1),
#  ('protested,', 1),
#  ('woods', 8),
#  ('sending.', 3),
#  ('hanging', 27),
#  ('offendeth', 1),
#  ('instant;', 1),
#  ('beadsmen', 1),
#  ('gad', 1),
#  ('whither,', 7),
#  ('whither.', 2),
#  ('scold', 4),
#  ('nunnery', 1),
#  ('opener', 1),
#  ('mutinies', 3),
#  ('dance?', 4),
#  ('whither?', 8),
#  ('rests-that', 1),
#  ('out-night', 1),
#  ('benvolio', 4),
#  ('sea-sorrow.', 1),
#  ('wood!', 1),
#  ('goodman,', 1),
#  ('slothful', 1),
#  ('spider.', 1),
#  ("franklin's", 1),
#  ('spider,', 4),
#  ('wood,', 13),
#  ('chambermaids.', 1),
#  ('wood.', 8),
#  ("suck'd.", 1),
#  ('appropriation', 1),
#  ("imagin'd", 7),
#  ('wood;', 5),
#  ('bringing', 17),
#  ('fetter:', 1),
#  ("cropp'd", 5),
#  ('wooden', 8),
#  ('ha!-hey', 1),
#  ('seven?', 1),
#  ('wednesday', 14),
#  ('further:', 1),
#  ('laments,', 2),
#  ('belied;', 1),
#  ('seven.', 2),
#  ('seven,', 4),
#  ('sooty', 1),
#  ("tom's", 5),
#  ('overswear;', 1),
#  ('undeaf', 1),
#  ('sooth', 2),
#  ('sustaining', 2),
#  ('consenting', 3),
#  ('chin,', 4),
#  ('chin.', 6),
#  ("'hereafter'", 1),
#  ('errors', 11),
#  ('rhodes.', 1),
#  ('nature!', 6),
#  ('rhodes,', 4),
#  ('nature,', 71),
#  ('cyprus', 10),
#  ('nature.', 32),
#  ('indignity.', 5),
#  ('circumference.', 2),
#  ('unprovide', 1),
#  ("madman's", 4),
#  ('accessed,', 1),
#  ('razeth', 1),
#  ('nature?', 3),
#  ('skill.--good', 1),
#  ('nature:', 1),
#  ('nature;', 10),
#  ('titles;', 1),
#  ('crouch', 3),
#  ('chins', 2),
#  ("flap-ear'd", 1),
#  ('siward', 2),
#  ('meteors,', 1),
#  ('wrest,', 1),
#  ('chine', 1),
#  ('complainer,', 1),
#  ('titles,', 5),
#  ('titles.', 1),
#  ("sluic'd", 2),
#  ('boblibindo', 1),
#  ('letters-this', 1),
#  ('clapper-de-claw', 1),
#  ('error:', 1),
#  ('climbed', 1),
#  ('tooth,', 3),
#  ('controversy', 5),
#  ('grecians?', 1),
#  ('xiv.', 1),
#  ('natures', 14),
#  ('stock,', 8),
#  ('error,', 7),
#  ('error.', 4),
#  ('ycleped', 1),
#  ('circumstance,', 7),
#  ('golden', 90),
#  ('circumstance.', 5),
#  ('projection', 1),
#  ('athenian.', 13),
#  ('him-no', 1),
#  ('popular?', 1),
#  ('lengthen', 2),
#  ('circumstance?', 2),
#  ('circumstance:', 1),
#  ('stern', 25),
#  ('unearned', 1),
#  ('befits,', 1),
#  ('speeches,', 4),
#  ('homespuns', 1),
#  ('studded', 1),
#  ('oft;', 2),
#  ('ascii,', 2),
#  ('sternest', 1),
#  ('ascii.', 1),
#  ('extremity;', 1),
#  ('footman?', 1),
#  ('jerusalem;', 2),
#  ('vicegerent', 1),
#  ('leading,', 1),
#  ('ascii"', 2),
#  ('music', 96),
#  ('therefore', 459),
#  ('oft-', 1),
#  ('oft,', 11),
#  ('swoopstake', 1),
#  ('sermons', 1),
#  ('praiseworthy.', 1),
#  ('russet-pated', 1),
#  ("t'envelop", 1),
#  ('homily', 1),
#  ('pregnantly', 1),
#  ('upbraidings', 1),
#  ('unpack', 1),
#  ('cobbler,', 1),
#  ('circumstances', 6),
#  ("captain's", 6),
#  ('locked', 1),
#  ('degrees;', 1),
#  ('catch:', 1),
#  ('liability,', 3),
#  ('degrees?', 1),
#  ('familiarity-', 1),
#  ('catch,', 4),
#  ('turtle-doves', 1),
#  ('degrees.', 3),
#  ('rocks.', 2),
#  ('wand', 1),
#  ('wane', 1),
#  ('unjust', 13),
#  ('reignier', 8),
#  ('slavery.', 1),
#  ('kingdoms', 21),
#  ('want', 115),
#  ("by'r", 17),
#  ('footed;', 1),
#  ('cookery', 1),
#  ("by't", 1),
#  ('absolute', 28),
#  ('well-armed', 1),
#  ('rites?', 1),
#  ('rites:', 2),
#  ("spurn'd", 1),
#  ('travel', 21),
#  ('copious', 1),
#  ('rites,', 1),
#  ('rites.', 2),
#  ('shunning', 1),
#  ('bowls.', 1),
#  ('canaries', 1),
#  ('cadence', 1),
#  ("o'er-snowed", 1),
#  ('oceans', 1),
#  ('show:', 1),
#  ('arch-villain', 1),
#  ('chameleon,', 1),
#  ('saintlike', 1),
#  ('halloing', 2),
#  ("greatness,'-", 1),
#  ('wrong', 116),
#  ('scornfully.', 1),
#  ('chameleon.', 1),
#  ("engag'd", 9),
#  ('pint,', 1),
#  ('unshunnable,', 1),
#  ('decorum.', 1),
#  ('wan?', 1),
#  ('4,', 1),
#  ('[kills', 1),
#  ('clew;', 1),
#  ("death-mark'd", 1),
#  ('retired,', 1),
#  ('reported?', 1),
#  ('whore?', 4),
#  ('misgives', 2),
#  ('wiltshire?', 1),
#  ('prophesier.', 1),
#  ('effect!', 2),
#  ('effect.', 8),
#  ('effect,', 9),
#  ('rudder.', 1),
#  ('halfpence.', 1),
#  ('[calling]', 1),
#  ('whizzing', 1),
#  ('damnable,', 1),
#  ('summer-swelling', 1),
#  ('sharply.', 1),
#  ('sharply,', 2),
#  ('bald,', 3),
#  ("tam'd", 4),
#  ('damnable.', 3),
#  ('ostent,', 1),
#  ('effect;', 4),
#  ('welcomer', 1),
#  ('welcomes', 2),
#  ('grunt,', 1),
#  ('wetting;', 1),
#  ('flower.', 7),
#  ('fit', 132),
#  ('fix', 4),
#  ('mayst', 62),
#  ("deform'd.", 1),
#  ("deform'd,", 1),
#  ('worms.', 2),
#  ('rescued', 4),
#  ('worms,', 5),
#  ('metres,', 1),
#  ('fig', 3),
#  ('fie', 30),
#  ('wales', 15),
#  ('malignant,', 1),
#  ('fin', 1),
#  ('worms!', 1),
#  ('welcome,', 119),
#  ('welcome-', 2),
#  ('welcome.', 63),
#  ('ostents', 1),
#  ('backing!', 1),
#  ('bristle', 4),
#  ('unpeg', 1),
#  ('welcome!', 13),
#  ('onset,', 1),
#  ('frosts', 4),
#  ('removedness;', 1),
#  ('twits', 1),
#  ('welcome?', 1),
#  ('effects', 19),
#  ('peu,', 1),
#  ('welcome;', 9),
#  ('sixteen', 11),
#  ('faction!', 1),
#  ('bankrupt.', 1),
#  ('bankrupt,', 2),
#  ('egg!', 2),
#  ('truant,', 3),
#  ('truant.', 1),
#  ('audrey-', 1),
#  ('audrey,', 5),
#  ('troublous', 4),
#  ('audrey.', 17),
#  ('seven;', 1),
#  ('lovers;', 1),
#  ('bewept', 3),
#  ('arrow', 5),
#  ('audrey;', 4),
#  ('burial', 9),
#  ('chiron.', 30),
#  ('chiron,', 11),
#  ('chiron-', 1),
#  ('solidares', 1),
#  ('baggage!', 2),
#  ('correct,', 1),
#  ('flower?', 1),
#  ("'will'", 2),
#  ('phoenicians', 1),
#  ('chiron;', 1),
#  ('abbot.', 2),
#  ("gagg'd.", 1),
#  ('allay', 9),
#  ('love-song.', 1),
#  ('self.', 8),
#  ('self-', 3),
#  ('self,', 24),
#  ('self)', 1),
#  ('indiscretion', 2),
#  ('brutish', 4),
#  ('gradation', 1),
#  ('unclog', 1),
#  ('mallows.', 1),
#  ('encourage', 4),
#  ('arm-the', 1),
#  ("th'art", 20),
#  ("wasp's", 1),
#  ('chances,', 2),
#  ('ashouting.', 1),
#  ('smithfield', 3),
#  ('sheep', 17),
#  ("endur'd.", 2),
#  ('wreaks,', 1),
#  ("endur'd!", 2),
#  ('justice-like', 1),
#  ('parasite,', 2),
#  ('forswearing,', 1),
#  ('redeemed', 1),
#  ('corrects', 1),
#  ("endur'd;", 1),
#  ('berwick', 2),
#  ('numbness,', 1),
#  ('jugs', 1),
#  ('nuncle.', 2),
#  ('nuncle,', 11),
#  ('south-west', 1),
#  ('vulcan', 3),
#  ("mad-brain'd", 3),
#  ('nuncle?', 2),
#  ('disturbed', 2),
#  ('guardians,', 1),
#  ('chiron]', 1),
#  ('kitchens,', 1),
#  ('moated', 2),
#  ('whipster', 1),
#  ("'coriolanus'", 1),
#  ("'cerns", 1),
#  ('lusts,', 1),
#  ('disfigured', 1),
#  ('reward;', 3),
#  ('preambulate;', 1),
#  ('maladies', 2),
#  ('reward?', 1),
#  ('lusts;', 1),
#  ("inform'd,", 1),
#  ('clamorous', 11),
#  ('signiories,', 1),
#  ('ways]', 1),
#  ('reward,', 4),
#  ('reward.', 9),
#  ('revania', 1),
#  ('service', 332),
#  ("sentenc'd-", 1),
#  ('quagmire;', 1),
#  ('confessor.', 1),
#  ('lisping,', 1),
#  ('needed', 3),
#  ('master', 506),
#  ('say]', 2),
#  ("o'erthrows", 1),
#  ('rewards', 6),
#  ("honour'd,", 2),
#  ('chin;', 1),
#  ("perturb'd", 1),
#  ('accords.', 1),
#  ('positively', 2),
#  ("displac'd;", 1),
#  ("'horn'--a", 1),
#  ('old;', 6),
#  ('craved', 1),
#  ('old?', 2),
#  ("sparta's", 1),
#  ('old!', 1),
#  ('idle', 58),
#  ('sheen', 1),
#  ('groats;', 1),
#  ('feeling', 26),
#  ('old,', 57),
#  ('old.', 22),
#  ('heads!', 2),
#  ('longs', 9),
#  ('heads,', 22),
#  ('heads.', 15),
#  ('panthino;', 1),
#  ('targe', 1),
#  ("head-i'll", 1),
#  ('athversary-', 1),
#  ('dozed', 1),
#  ('undutiful.', 1),
#  ('meekness,', 1),
#  ('thaw', 2),
#  ('heads?', 1),
#  ('claribel.', 1),
#  ('heads;', 4),
#  ('dozen', 30),
#  ('poorest,', 2),
#  ('affairs', 39),
#  ('wholesome', 28),
#  ("subdu'd", 8),
#  ('hymen', 5),
#  ('fugitive!', 1),
#  ('uncouth', 2),
#  ('bankrout,', 1),
#  ('foemen,', 1),
#  ('purge,', 2),
#  ("pronounc'd.", 3),
#  ('purge.', 1),
#  ('willing,', 5),
#  ('fugitive?', 1),
#  ('willing.', 2),
#  ('appertain', 2),
#  ('long;', 17),
#  ('audacity,', 1),
#  ('long?', 7),
#  ('committing', 4),
#  ('heath', 2),
#  ('pelting', 6),
#  ('vexing', 1),
#  ('violence-', 1),
#  ("scann'd.", 2),
#  ('toil', 13),
#  ("scann'd,", 1),
#  ('mouth', 64),
#  ('long.', 47),
#  ('reverence', 20),
#  ("bane.'", 1),
#  ('relieving', 1),
#  ('long!', 3),
#  ('pygmies--rather', 1),
#  ('expound', 4),
#  ('singer', 1),
#  ('singes', 1),
#  ('unripe,', 1),
#  ("'element'", 1),
#  ("whosoe'er", 1),
#  ('habiliments;', 1),
#  ('inseparable.', 1),
#  ('inseparable,', 1),
#  ('ache,', 3),
#  ('indignity,', 1),
#  ('heads]', 2),
#  ('habiliments,', 1),
#  ('affair.', 7),
#  ('purged', 3),
#  ('affair,', 1),
#  ('variable,', 1),
#  ('hermitage,', 2),
#  ('saying', 43),
#  ('ponds.', 1),
#  ('earnest-gaping', 1),
#  ('gives.', 2),
#  ('plat,', 1),
#  ('tempter', 2),
#  ("father's,", 2),
#  ("father's.", 5),
#  ('occupation,', 2),
#  ('fennel', 1),
#  ('ulcer', 1),
#  ('hooded,', 1),
#  ('tempted', 10),
#  ('cheaply', 1),
#  ("father's?", 2),
#  ('\xef\xbb\xbfthe', 1),
#  ('apace', 3),
#  ('peck', 8),
#  ('themselves]', 1),
#  ('kerns', 4),
#  ('extemporal', 3),
#  ("baby's", 1),
#  ('neighs', 2),
#  ('eyelid.', 1),
#  ('bliss', 8),
#  ('rich', 134),
#  ('true-to', 1),
#  ('rice', 1),
#  ('pardons,', 2),
#  ('pardons.', 2),
#  ('plate', 4),
#  ('frankly.', 1),
#  ("olivia's", 14),
#  ('unfathered,', 1),
#  ('guileful', 2),
#  ("d'une,", 1),
#  ('altogether', 20),
#  ('affronted', 1),
#  ('givest', 3),
#  ('uncleanliness', 1),
#  ('hovel', 1),
#  ("honesty's", 1),
#  ('conquerors', 2),
#  ("'accommodated!'", 1),
#  ('nicely', 7),
#  ('unhallowed', 6),
#  ('patch', 10),
#  ('neigh,', 2),
#  ('eyelids', 11),
#  ('kern,', 1),
#  ("leader's", 1),
#  ('shocks', 3),
#  ('boarded', 7),
#  ('partial.', 1),
#  ("shak'd;", 1),
#  ("knock'd", 9),
#  ('scantling', 1),
#  ("swill'd", 1),
#  ('overborne', 4),
#  ("tarr'd", 1),
#  ('unready!', 1),
#  ("shak'd,", 1),
#  ('reasons!', 1),
#  ('household,', 1),
#  ('monastery;', 2),
#  ('lots', 2),
#  ('murky.', 1),
#  ('plaintful', 1),
#  ('droven', 1),
#  ('exhalation', 2),
#  ('ira', 1),
#  ('foot-licker.', 1),
#  ('advantaged,', 1),
#  ('ire', 2),
#  ('requisites', 1),
#  ('letting', 7),
#  ('eleanor!', 1),
#  ('pardoned,', 1),
#  ('extend', 14),
#  ('nature', 218),
#  ('visions;', 1),
#  ("prevail'd", 14),
#  ('embracement', 1),
#  ('crystals.', 1),
#  ('unseemly', 1),
#  ('extent', 5),
#  ('dorsetshire', 1),
#  ('meteors.', 1),
#  ('tyranny', 15),
#  ("fenc'd", 1),
#  ("o'ertrip", 1),
#  ('suppliest', 1),
#  ('heating', 1),
#  ('incense', 9),
#  ('xv.', 1),
#  ("compil'd,", 1),
#  ('pomgarnet,', 1),
#  ('directly.', 5),
#  ('directly,', 3),
#  ('mortified', 4),
#  ('twenty-three', 2),
#  ('doubt!', 1),
#  ("butterwoman's", 1),
#  ('doubt,', 32),
#  ('doubt-', 1),
#  ('doubt.', 9),
#  ("julia.'", 2),
#  ('mask?', 1),
#  ('\'"lo,', 2),
#  ('charnel', 2),
#  ('behalf-', 1),
#  ('abused,', 3),
#  ('down-gyved', 1),
#  ('doubt?', 2),
#  ("whoso'er", 1),
#  ('doubt:', 1),
#  ('godhead', 3),
#  ('apples;', 1),
#  ('coal-black', 5),
#  ('union', 5),
#  ('remained', 2),
#  ('fro', 3),
#  ('studious', 2),
#  ('.', 49),
#  ('muck', 1),
#  ("pack'd.-", 1),
#  ('boatswain.', 12),
#  ('much', 891),
#  ('meteors?', 1),
#  ("o'erswell", 2),
#  ('macbeth.', 225),
#  ('fry', 3),
#  ('despairing,', 2),
#  ('[descending]', 1),
#  ('apples!', 1),
#  ('libya.', 1),
#  ("follow'd", 18),
#  ('libya,', 1),
#  ('wags', 2),
#  ('spit', 21),
#  ('chamberlain', 11),
#  ('davy', 7),
#  ("kinsman's.", 1),
#  ('libya;', 1),
#  ('doubts', 7),
#  ('right-hand;', 1),
#  ('descry.', 2),
#  ('spin', 3),
#  ('keepers.', 1),
#  ('such-like', 5),
#  ('keepers,', 3),
#  ('misconstrues', 1),
#  ("strew'd", 8),
#  ("bold'st", 1),
#  ('rightly,', 3),
#  ('crupper', 1),
#  ('rightly.', 2),
#  ('employ', 21),
#  ('divineness', 1),
#  ('groats', 4),
#  ('starings,', 1),
#  ('prostrate', 5),
#  ('consent!', 1),
#  ('consent.', 7),
#  ('consent,', 25),
#  ('jacksauce', 1),
#  ('to-morrow', 113),
#  ('consent:', 1),
#  ('consent;', 2),
#  ('south,', 8),
#  ('swift-winged', 2),
#  ('consent?', 1),
#  ('title-leaf,', 1),
#  ('degenerate,', 3),
#  ('bricklayer', 1),
#  ('memorial', 3),
#  ('horseback;', 2),
#  ("accomplish'd;", 2),
#  ('well-born', 1),
#  ('shards,', 2),
#  ('agincourt?', 1),
#  ('wheezing', 1),
#  ("accomplish'd.", 1),
#  ('split', 8),
#  ("flowerets'", 1),
#  ('freeness', 1),
#  ('marches', 5),
#  ("disclos'd,", 3),
#  ('frenchmen', 10),
#  ("disclos'd.", 1),
#  ('genders?', 1),
#  ("scal'd", 1),
#  ('consents', 3),
#  ('verge,', 1),
#  ('supper', 22),
#  ('mandragora,', 1),
#  ('mandragora.', 1),
#  ('dolabella', 6),
#  ('differences,', 2),
#  ('differences.', 1),
#  ('provincial.', 1),
#  ('visitation.', 4),
#  ('visitation-', 1),
#  ('peremptory', 7),
#  ('brine,', 2),
#  ('visitation;', 1),
#  ('worcester.', 4),
#  ('stillness', 5),
#  ('principal;', 1),
#  ('visitation?', 1),
#  ('stringless', 1),
#  ('enceladus,', 1),
#  ("subject's", 3),
#  ('euphronius', 2),
#  ('malefactor.', 1),
#  ('corporate', 2),
#  ('brine;', 2),
#  ('elder;', 1),
#  ('bellow', 1),
#  ('foreigners', 1),
#  ('circumstance-', 1),
#  ('bought;', 2),
#  ('maketh', 3),
#  ('outlives', 3),
#  ('elder,', 4),
#  ('elder-', 1),
#  ('swooned,', 1),
#  ('brandish', 3),
#  ('endue', 2),
#  ('countermand;', 1),
#  ("eas'd", 1),
#  ('trinculo', 7),
#  ('had', 1373),
#  ('advancement', 4),
#  ('hag', 3),
#  ('speeches?', 2),
#  ('gad?', 1),
#  ('beloved', 25),
#  ('smelt,', 1),
#  ('hap', 19),
#  ('has', 371),
#  ('hat', 15),
#  ('elders', 1),
#  ('confection', 1),
#  ('lass?', 1),
#  ('haberdasher.', 1),
#  ("qu'ai", 1),
#  ('continuantly', 1),
#  ('trinculos?', 1),
#  ('wag!', 1),
#  ('shadow', 48),
#  ('enough-of', 1),
#  ('lass,', 1),
#  ('joineth', 1),
#  ('dallying.', 1),
#  ('bray,', 1),
#  ('ha,', 60),
#  ("picture's", 1),
#  ("resolv'd,", 5),
#  ('ha!', 105),
#  ("resolv'd!", 1),
#  ('alice', 4),
#  ('[exeunt.', 1),
#  ("ha'", 27),
#  ("resolv'd;", 2),
#  ("resolv'd:", 1),
#  ('threadbare.', 1),
#  ('espouse.', 2),
#  ('ha?', 22),
#  ('peace-parted', 1),
#  ('unreprievable', 1),
#  ('effusion', 4),
#  ('attorney', 4),
#  ('wag.', 2),
#  ('disdain,', 6),
#  ('crowd', 5),
#  ('disdain!', 1),
#  ('scathe', 4),
#  ('circumstance;', 2),
#  ('crown', 123),
#  ('begin', 75),
#  ('madman].', 1),
#  ('captive', 12),
#  ('disdain:', 2),
#  ('disdain;', 3),
#  ('casket?', 1),
#  ('frame?', 2),
#  ('treaty.-', 1),
#  ('speeches-', 1),
#  ('hoo-oo!', 1),
#  ('haste-post-haste', 1),
#  ('perchance', 40),
#  ('bottom', 33),
#  ('inhuman', 6),
#  ('fencing,', 2),
#  ('plucked', 2),
#  ('soon.-', 1),
#  ('impossible;', 3),
#  ('nightwork', 1),
#  ('scath,', 1),
#  ('sporting-place.', 1),
#  ('sprightful', 1),
#  ('totally.', 1),
#  ('crow.', 4),
#  ('crow,', 7),
#  ('julia', 20),
#  ("impawn'd,", 1),
#  ("reach'd.", 1),
#  ('stoccadoes,', 1),
#  ('oft?', 1),
#  ('disdains', 5),
#  ('crow?', 1),
#  ("incorps'd", 1),
#  ('bencher', 1),
#  ('benches', 1),
#  ('attendants].', 8),
#  ('ingenious?', 2),
#  ('aright.', 3),
#  ('casket]', 3),
#  ("cover'd", 7),
#  ('bides', 1),
#  ('ingenious,', 3),
#  ('sodden-witted', 1),
#  ('ingenious.', 1),
#  ('university.', 1),
#  ('university,', 1),
#  ('aufidius?', 2),
#  ('bullcalf', 3),
#  ("aufidius'", 4),
#  ('valleys', 1),
#  ('aufidius!', 1),
#  ('dites-moi', 2),
#  ('aufidius,', 19),
#  ('shoots', 6),
#  ('aufidius.', 47),
#  ('perfume,', 1),
#  ('perfume.', 2),
#  ('due.', 6),
#  ('due,', 8),
#  ('despised', 11),
#  ('reword;', 1),
#  ('serving,', 1),
#  ('suffice', 5),
#  ('humble,', 2),
#  ('humble.', 3),
#  ('tame', 23),
#  ('fore-goers.', 1),
#  ('due?', 1),
#  ('shoot]', 1),
#  ('despiser', 1),
#  ('staffordshire,', 1),
#  ('array,', 5),
#  ('rapes', 1),
#  ('footman,', 3),
#  ('contusions', 1),
#  ('revenues,', 2),
#  ('alexandrian', 2),
#  ('oft.', 3),
#  ('being!', 1),
#  ('perfumes', 5),
#  ('shoot,', 1),
#  ('shoot.', 7),
#  ('marshal.', 11),
#  ('marshal,', 8),
#  ('being-', 1),
#  ('being,', 14),
#  ("hallow'd", 4),
#  ('being.', 1),
#  ('say:', 7),
#  ('shoot:', 1),
#  ('perfumed', 4),
#  ("peer-out!'", 1),
#  ('being;', 1),
#  ('safeguard', 7),
#  ('marshal;', 1),
#  ('groom,', 2),
#  ('groom.', 14),
#  ('humbled', 7),
#  ("t'allay", 1),
#  ('rape-', 1),
#  ('rape,', 3),
#  ("oft'", 1),
#  ('despise,', 2),
#  ('rape;', 1),
#  ('onions;', 1),
#  ('humbles', 1),
#  ('groom;', 1),
#  ('alexandria,', 1),
#  ('dues', 3),
#  ('alexandria.', 18),
#  ('crown]', 4),
#  ('superficially;', 1),
#  ('disgrace', 33),
#  ('marullus', 1),
#  ("ancient'st", 1),
#  ('palm?', 1),
#  ('palm;', 1),
#  ('extenuates', 1),
#  ("accommodated!'", 1),
#  ('superficially.', 1),
#  ('northamptonshire,', 1),
#  ("blush'd,", 1),
#  ('palm,', 5),
#  ('thousands:', 1),
#  ('sympathy', 4),
#  ('gratii,', 1),
#  ('minds!', 3),
#  ('minds.', 2),
#  ('minds-', 2),
#  ('minds,', 11),
#  ("as's", 1),
#  ('crowns', 26),
#  ('[verges].', 1),
#  ('hapless,', 1),
#  ('vanquisher,', 1),
#  ('vanquisher.', 1),
#  ('lucilius,', 11),
#  ('woodcocks!', 1),
#  ('tamely', 1),
#  ('sunset', 3),
#  ('minds;', 1),
#  ('roll', 5),
#  ("lucilius'", 1),
#  ("gone.'", 1),
#  ("cloth-o'-gold", 1),
#  ('intend', 43),
#  ('palms', 2),
#  ("sinon's", 1),
#  ('lump,', 2),
#  ('palmy', 1),
#  ('extenuate-', 1),
#  ('transported', 8),
#  ('scylla,', 1),
#  ('comely', 6),
#  ('intent', 26),
#  ("razor's", 1),
#  ('smelling', 5),
#  ('variable', 4),
#  ('dispersed', 1),
#  ('pausingly', 1),
#  ('crown?', 15),
#  ('[descends', 1),
#  ("between's.", 2),
#  ('palm]', 1),
#  ('commended,', 1),
#  ('alton,', 1),
#  ('crown-', 1),
#  ('crown,', 56),
#  ('crown.', 37),
#  ("bark'st", 1),
#  ('crown!', 2),
#  ("lancaster!']", 1),
#  ("happ'd!", 1),
#  ('gown', 17),
#  ('proficient', 1),
#  ('stay!', 5),
#  ('chain', 31),
#  ('whoever', 13),
#  ('stay,', 79),
#  ('stay-', 2),
#  ('stay.', 40),
#  ('[on', 1),
#  ('chivalry!', 1),
#  ('profits,', 1),
#  ('chivalry?', 1),
#  ("cradle's", 1),
#  ('couchings', 1),
#  ('balmy', 3),
#  ('chivalry;', 2),
#  ('by-peeping', 1),
#  ('nayward.', 1),
#  ('chair', 16),
#  ('good?', 17),
#  ('willoughby,', 4),
#  ('stay:', 3),
#  ('stay;', 22),
#  ('schoolboys', 1),
#  ('grapples', 1),
#  ('foaming', 5),
#  ('browsing', 1),
#  ("when's", 1),
#  ('cook;', 1),
#  ('honour-', 4),
#  ('child]', 4),
#  ('cook?', 2),
#  ("when't", 1),
#  ('i-not', 1),
#  ("squand'ring", 1),
#  ('losing.', 1),
#  ('blackmere,', 1),
#  ("'fool'--a", 1),
#  ('cobbler.', 1),
#  ('cook-', 1),
#  ('cook,', 5),
#  ("'down,", 1),
#  ('cook.', 2),
#  ('egypt!', 1),
#  ('apt!', 1),
#  ("lawyer's,", 1),
#  ('child:', 1),
#  ('child;', 21),
#  ('egypt-', 1),
#  ('egypt,', 9),
#  ('olympus', 1),
#  ('choice', 36),
#  ('child!', 10),
#  ('embark', 2),
#  ('gloomy', 2),
#  ('stays', 32),
#  ('apt;', 1),
#  ('apt:', 1),
#  ('egypt;', 4),
#  ('exact', 7),
#  ('child-', 1),
#  ('minute', 25),
#  ('pride,', 22),
#  ('cooks', 1),
#  ('curtis.', 22),
#  ('psalteries,', 1),
#  ("siz'd,", 1),
#  ('just?', 2),
#  ('gorgon.', 1),
#  ('gorgon,', 1),
#  ('supply,', 3),
#  ('continuate', 2),
#  ('grapple.', 1),
#  ('compressed,', 1),
#  ("soe'er,", 2),
#  ('shylock', 12),
#  ('brows!', 2),
#  ('copyrighted', 2),
#  ('braggardism', 1),
#  ('chopping', 1),
#  ('shirts', 4),
#  ('climb,', 2),
#  ("show'st", 2),
#  ("measur'd", 8),
#  ('adorns', 1),
#  ('servingman.', 7),
#  ('servingman,', 1),
#  ('dust;', 3),
#  ('irregular,', 1),
#  ('wreath', 3),
#  ('dust?', 3),
#  ('grief-shot', 1),
#  ('ornament-', 1),
#  ('laughter!', 1),
#  ('celebrates', 1),
#  ('dust,', 11),
#  ('dust.', 11),
#  ('trail;', 1),
#  ('ornament.', 2),
#  ("o'erteemed", 1),
#  ('madame;', 2),
#  ('shirt.', 3),
#  ('honour', 347),
#  ('shirt,', 3),
#  ("antony's", 10),
#  ('plucking', 6),
#  ("let'st", 3),
#  ...]

# %%
#same statement again
max(shakespeare_count_list,key = lambda x:x[1])
# Out:
# ('the', 27729)

# %% [markdown]
# <pre>
# The is used the most by him
# </pre>

# %%
words_shakespeare_list
# Out:
# ['\xef\xbb\xbfthe',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare,',
#  'by',
#  'william',
#  'shakespeare',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'you',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '**',
#  'this',
#  'is',
#  'a',
#  'copyrighted',
#  'project',
#  'gutenberg',
#  'ebook,',
#  'details',
#  'below',
#  '**',
#  '**',
#  'please',
#  'follow',
#  'the',
#  'copyright',
#  'guidelines',
#  'in',
#  'this',
#  'file.',
#  '**',
#  'title:',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'author:',
#  'william',
#  'shakespeare',
#  'posting',
#  'date:',
#  'september',
#  '1,',
#  '2011',
#  '[ebook',
#  '#100]',
#  'release',
#  'date:',
#  'january,',
#  '1994',
#  'language:',
#  'english',
#  '***',
#  'start',
#  'of',
#  'this',
#  'project',
#  'gutenberg',
#  'ebook',
#  'complete',
#  'works--william',
#  'shakespeare',
#  '***',
#  'produced',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'from',
#  'their',
#  'library',
#  'of',
#  'the',
#  'future',
#  'this',
#  'is',
#  'the',
#  '100th',
#  'etext',
#  'file',
#  'presented',
#  'by',
#  'project',
#  'gutenberg,',
#  'and',
#  'is',
#  'presented',
#  'in',
#  'cooperation',
#  'with',
#  'world',
#  'library,',
#  'inc.,',
#  'from',
#  'their',
#  'library',
#  'of',
#  'the',
#  'future',
#  'and',
#  'shakespeare',
#  'cdroms.',
#  'project',
#  'gutenberg',
#  'often',
#  'releases',
#  'etexts',
#  'that',
#  'are',
#  'not',
#  'placed',
#  'in',
#  'the',
#  'public',
#  'domain!!',
#  'shakespeare',
#  '*this',
#  'etext',
#  'has',
#  'certain',
#  'copyright',
#  'implications',
#  'you',
#  'should',
#  'read!*',
#  '<<this',
#  'electronic',
#  'version',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'is',
#  'copyright',
#  '1990-1993',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'and',
#  'is',
#  'provided',
#  'by',
#  'project',
#  'gutenberg',
#  'etext',
#  'of',
#  'illinois',
#  'benedictine',
#  'college',
#  'with',
#  'permission.',
#  'electronic',
#  'and',
#  'machine',
#  'readable',
#  'copies',
#  'may',
#  'be',
#  'distributed',
#  'so',
#  'long',
#  'as',
#  'such',
#  'copies',
#  '(1)',
#  'are',
#  'for',
#  'your',
#  'or',
#  'others',
#  'personal',
#  'use',
#  'only,',
#  'and',
#  '(2)',
#  'are',
#  'not',
#  'distributed',
#  'or',
#  'used',
#  'commercially.',
#  'prohibited',
#  'commercial',
#  'distribution',
#  'includes',
#  'by',
#  'any',
#  'service',
#  'that',
#  'charges',
#  'for',
#  'download',
#  'time',
#  'or',
#  'for',
#  'membership.>>',
#  '*project',
#  'gutenberg',
#  'is',
#  'proud',
#  'to',
#  'cooperate',
#  'with',
#  'the',
#  'world',
#  'library*',
#  'in',
#  'the',
#  'presentation',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'for',
#  'your',
#  'reading',
#  'for',
#  'education',
#  'and',
#  'entertainment.',
#  'however,',
#  'this',
#  'is',
#  'neither',
#  'shareware',
#  'nor',
#  'public',
#  'domain.',
#  '.',
#  '.and',
#  'under',
#  'the',
#  'library',
#  'of',
#  'the',
#  'future',
#  'conditions',
#  'of',
#  'this',
#  'presentation.',
#  '.',
#  '.no',
#  'charges',
#  'may',
#  'be',
#  'made',
#  'for',
#  '*any*',
#  'access',
#  'to',
#  'this',
#  'material.',
#  'you',
#  'are',
#  'encouraged!!',
#  'to',
#  'give',
#  'it',
#  'away',
#  'to',
#  'anyone',
#  'you',
#  'like,',
#  'but',
#  'no',
#  'charges',
#  'are',
#  'allowed!!',
#  '*****',
#  'small',
#  'print!',
#  'for',
#  'complete',
#  'shakespeare',
#  '*****',
#  'this',
#  'electronic',
#  'version',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'is',
#  'copyright',
#  '1990-1993',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'and',
#  'is',
#  'provided',
#  'by',
#  'project',
#  'gutenberg',
#  'etext',
#  'of',
#  'illinois',
#  'benedictine',
#  'college',
#  'with',
#  'permission.',
#  'since',
#  'unlike',
#  'many',
#  'other',
#  'project',
#  'gutenberg-tm',
#  'etexts,',
#  'this',
#  'etext',
#  'is',
#  'copyright',
#  'protected,',
#  'and',
#  'since',
#  'the',
#  'materials',
#  'and',
#  'methods',
#  'you',
#  'use',
#  'will',
#  'effect',
#  'the',
#  "project's",
#  'reputation,',
#  'your',
#  'right',
#  'to',
#  'copy',
#  'and',
#  'distribute',
#  'it',
#  'is',
#  'limited',
#  'by',
#  'the',
#  'copyright',
#  'and',
#  'other',
#  'laws,',
#  'and',
#  'by',
#  'the',
#  'conditions',
#  'of',
#  'this',
#  '"small',
#  'print!"',
#  'statement.',
#  '1.',
#  'license',
#  'a)',
#  'you',
#  'may',
#  '(and',
#  'are',
#  'encouraged)',
#  'to',
#  'distribute',
#  'electronic',
#  'and',
#  'machine',
#  'readable',
#  'copies',
#  'of',
#  'this',
#  'etext,',
#  'so',
#  'long',
#  'as',
#  'such',
#  'copies',
#  '(1)',
#  'are',
#  'for',
#  'your',
#  'or',
#  'others',
#  'personal',
#  'use',
#  'only,',
#  'and',
#  '(2)',
#  'are',
#  'not',
#  'distributed',
#  'or',
#  'used',
#  'commercially.',
#  'prohibited',
#  'commercial',
#  'distribution',
#  'includes',
#  'by',
#  'any',
#  'service',
#  'that',
#  'charges',
#  'for',
#  'download',
#  'time',
#  'or',
#  'for',
#  'membership.',
#  'b)',
#  'this',
#  'license',
#  'is',
#  'subject',
#  'to',
#  'the',
#  'conditions',
#  'that',
#  'you',
#  'honor',
#  'the',
#  'refund',
#  'and',
#  'replacement',
#  'provisions',
#  'of',
#  'this',
#  '"small',
#  'print!"',
#  'statement;',
#  'and',
#  'that',
#  'you',
#  'distribute',
#  'exact',
#  'copies',
#  'of',
#  'this',
#  'etext,',
#  'including',
#  'this',
#  'small',
#  'print',
#  'statement.',
#  'such',
#  'copies',
#  'can',
#  'be',
#  'compressed',
#  'or',
#  'any',
#  'proprietary',
#  'form',
#  '(including',
#  'any',
#  'form',
#  'resulting',
#  'from',
#  'word',
#  'processing',
#  'or',
#  'hypertext',
#  'software),',
#  'so',
#  'long',
#  'as',
#  '*either*:',
#  '(1)',
#  'the',
#  'etext,',
#  'when',
#  'displayed,',
#  'is',
#  'clearly',
#  'readable,',
#  'and',
#  'does',
#  '*not*',
#  'contain',
#  'characters',
#  'other',
#  'than',
#  'those',
#  'intended',
#  'by',
#  'the',
#  'author',
#  'of',
#  'the',
#  'work,',
#  'although',
#  'tilde',
#  '(~),',
#  'asterisk',
#  '(*)',
#  'and',
#  'underline',
#  '(_)',
#  'characters',
#  'may',
#  'be',
#  'used',
#  'to',
#  'convey',
#  'punctuation',
#  'intended',
#  'by',
#  'the',
#  'author,',
#  'and',
#  'additional',
#  'characters',
#  'may',
#  'be',
#  'used',
#  'to',
#  'indicate',
#  'hypertext',
#  'links;',
#  'or',
#  '(2)',
#  'the',
#  'etext',
#  'is',
#  'readily',
#  'convertible',
#  'by',
#  'the',
#  'reader',
#  'at',
#  'no',
#  'expense',
#  'into',
#  'plain',
#  'ascii,',
#  'ebcdic',
#  'or',
#  'equivalent',
#  'form',
#  'by',
#  'the',
#  'program',
#  'that',
#  'displays',
#  'the',
#  'etext',
#  '(as',
#  'is',
#  'the',
#  'case,',
#  'for',
#  'instance,',
#  'with',
#  'most',
#  'word',
#  'processors);',
#  'or',
#  '(3)',
#  'you',
#  'provide',
#  'or',
#  'agree',
#  'to',
#  'provide',
#  'on',
#  'request',
#  'at',
#  'no',
#  'additional',
#  'cost,',
#  'fee',
#  'or',
#  'expense,',
#  'a',
#  'copy',
#  'of',
#  'the',
#  'etext',
#  'in',
#  'plain',
#  'ascii.',
#  '2.',
#  'limited',
#  'warranty;',
#  'disclaimer',
#  'of',
#  'damages',
#  'this',
#  'etext',
#  'may',
#  'contain',
#  'a',
#  '"defect"',
#  'in',
#  'the',
#  'form',
#  'of',
#  'incomplete,',
#  'inaccurate',
#  'or',
#  'corrupt',
#  'data,',
#  'transcription',
#  'errors,',
#  'a',
#  'copyright',
#  'or',
#  'other',
#  'infringement,',
#  'a',
#  'defective',
#  'or',
#  'damaged',
#  'disk,',
#  'computer',
#  'virus,',
#  'or',
#  'codes',
#  'that',
#  'damage',
#  'or',
#  'cannot',
#  'be',
#  'read',
#  'by',
#  'your',
#  'equipment.',
#  'but',
#  'for',
#  'the',
#  '"right',
#  'of',
#  'replacement',
#  'or',
#  'refund"',
#  'described',
#  'below,',
#  'the',
#  'project',
#  '(and',
#  'any',
#  'other',
#  'party',
#  'you',
#  'may',
#  'receive',
#  'this',
#  'etext',
#  'from',
#  'as',
#  'a',
#  'project',
#  'gutenberg-tm',
#  'etext)',
#  'disclaims',
#  'all',
#  'liability',
#  'to',
#  'you',
#  'for',
#  'damages,',
#  'costs',
#  'and',
#  'expenses,',
#  'including',
#  'legal',
#  'fees,',
#  'and',
#  'you',
#  'have',
#  'no',
#  'remedies',
#  'for',
#  'negligence',
#  'or',
#  'under',
#  'strict',
#  'liability,',
#  'or',
#  'for',
#  'breach',
#  'of',
#  'warranty',
#  'or',
#  'contract,',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'indirect,',
#  'consequential,',
#  'punitive',
#  'or',
#  'incidental',
#  'damages,',
#  'even',
#  'if',
#  'you',
#  'give',
#  'notice',
#  'of',
#  'the',
#  'possibility',
#  'of',
#  'such',
#  'damages.',
#  'if',
#  'you',
#  'discover',
#  'a',
#  'defect',
#  'in',
#  'this',
#  'etext',
#  'within',
#  '90',
#  'days',
#  'of',
#  'receiv-',
#  'ing',
#  'it,',
#  'you',
#  'can',
#  'receive',
#  'a',
#  'refund',
#  'of',
#  'the',
#  'money',
#  '(if',
#  'any)',
#  'you',
#  'paid',
#  'for',
#  'it',
#  'by',
#  'sending',
#  'an',
#  'explanatory',
#  'note',
#  'within',
#  'that',
#  'time',
#  'to',
#  'the',
#  'person',
#  'you',
#  'received',
#  'it',
#  'from.',
#  'if',
#  'you',
#  'received',
#  'it',
#  'on',
#  'a',
#  'physical',
#  'medium,',
#  'you',
#  'must',
#  'return',
#  'it',
#  'with',
#  'your',
#  'note,',
#  'and',
#  'such',
#  'person',
#  'may',
#  'choose',
#  'to',
#  'alternatively',
#  'give',
#  'you',
#  'a',
#  'replacement',
#  'copy.',
#  'if',
#  'you',
#  'received',
#  'it',
#  'electronically,',
#  'such',
#  'person',
#  'may',
#  'choose',
#  'to',
#  'alternatively',
#  'give',
#  'you',
#  'a',
#  'second',
#  'opportunity',
#  'to',
#  'receive',
#  'it',
#  'electronically.',
#  'this',
#  'etext',
#  'is',
#  'otherwise',
#  'provided',
#  'to',
#  'you',
#  '"as-is".',
#  'no',
#  'other',
#  'warranties',
#  'of',
#  'any',
#  'kind,',
#  'express',
#  'or',
#  'implied,',
#  'are',
#  'made',
#  'to',
#  'you',
#  'as',
#  'to',
#  'the',
#  'etext',
#  'or',
#  'any',
#  'medium',
#  'it',
#  'may',
#  'be',
#  'on,',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'warranties',
#  'of',
#  'merchantability',
#  'or',
#  'fitness',
#  'for',
#  'a',
#  'particular',
#  'purpose.',
#  'some',
#  'states',
#  'do',
#  'not',
#  'allow',
#  'disclaimers',
#  'of',
#  'implied',
#  'warranties',
#  'or',
#  'the',
#  'exclusion',
#  'or',
#  'limitation',
#  'of',
#  'consequen-',
#  'tial',
#  'damages,',
#  'so',
#  'the',
#  'above',
#  'disclaimers',
#  'and',
#  'exclusions',
#  'may',
#  'not',
#  'apply',
#  'to',
#  'you,',
#  'and',
#  'you',
#  'may',
#  'have',
#  'other',
#  'legal',
#  'rights.',
#  '3.',
#  'indemnity:',
#  'you',
#  'will',
#  'indemnify',
#  'and',
#  'hold',
#  'the',
#  'project,',
#  'its',
#  'directors,',
#  'officers,',
#  'members',
#  'and',
#  'agents',
#  'harmless',
#  'from',
#  'all',
#  'lia-',
#  'bility,',
#  'cost',
#  'and',
#  'expense,',
#  'including',
#  'legal',
#  'fees,',
#  'that',
#  'arise',
#  'directly',
#  'or',
#  'indirectly',
#  'from',
#  'any',
#  'of',
#  'the',
#  'following',
#  'that',
#  'you',
#  'do',
#  'or',
#  'cause:',
#  '[a]',
#  'distribution',
#  'of',
#  'this',
#  'etext,',
#  '[b]',
#  'alteration,',
#  'modification,',
#  'or',
#  'addition',
#  'to',
#  'the',
#  'etext,',
#  'or',
#  '[c]',
#  'any',
#  'defect.',
#  '4.',
#  'what',
#  'if',
#  'you',
#  '*want*',
#  ...]

# %% [markdown]
# <h3> That first word doesn't make much sense -delete it </h3>

# %%
del words_shakespeare_list[0]

# %%
words_shakespeare_list #'\xef\xbb\xbfthe' gone there are a lot like this hidden
# Out:
# ['project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare,',
#  'by',
#  'william',
#  'shakespeare',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever.',
#  'you',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '**',
#  'this',
#  'is',
#  'a',
#  'copyrighted',
#  'project',
#  'gutenberg',
#  'ebook,',
#  'details',
#  'below',
#  '**',
#  '**',
#  'please',
#  'follow',
#  'the',
#  'copyright',
#  'guidelines',
#  'in',
#  'this',
#  'file.',
#  '**',
#  'title:',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'author:',
#  'william',
#  'shakespeare',
#  'posting',
#  'date:',
#  'september',
#  '1,',
#  '2011',
#  '[ebook',
#  '#100]',
#  'release',
#  'date:',
#  'january,',
#  '1994',
#  'language:',
#  'english',
#  '***',
#  'start',
#  'of',
#  'this',
#  'project',
#  'gutenberg',
#  'ebook',
#  'complete',
#  'works--william',
#  'shakespeare',
#  '***',
#  'produced',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'from',
#  'their',
#  'library',
#  'of',
#  'the',
#  'future',
#  'this',
#  'is',
#  'the',
#  '100th',
#  'etext',
#  'file',
#  'presented',
#  'by',
#  'project',
#  'gutenberg,',
#  'and',
#  'is',
#  'presented',
#  'in',
#  'cooperation',
#  'with',
#  'world',
#  'library,',
#  'inc.,',
#  'from',
#  'their',
#  'library',
#  'of',
#  'the',
#  'future',
#  'and',
#  'shakespeare',
#  'cdroms.',
#  'project',
#  'gutenberg',
#  'often',
#  'releases',
#  'etexts',
#  'that',
#  'are',
#  'not',
#  'placed',
#  'in',
#  'the',
#  'public',
#  'domain!!',
#  'shakespeare',
#  '*this',
#  'etext',
#  'has',
#  'certain',
#  'copyright',
#  'implications',
#  'you',
#  'should',
#  'read!*',
#  '<<this',
#  'electronic',
#  'version',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'is',
#  'copyright',
#  '1990-1993',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'and',
#  'is',
#  'provided',
#  'by',
#  'project',
#  'gutenberg',
#  'etext',
#  'of',
#  'illinois',
#  'benedictine',
#  'college',
#  'with',
#  'permission.',
#  'electronic',
#  'and',
#  'machine',
#  'readable',
#  'copies',
#  'may',
#  'be',
#  'distributed',
#  'so',
#  'long',
#  'as',
#  'such',
#  'copies',
#  '(1)',
#  'are',
#  'for',
#  'your',
#  'or',
#  'others',
#  'personal',
#  'use',
#  'only,',
#  'and',
#  '(2)',
#  'are',
#  'not',
#  'distributed',
#  'or',
#  'used',
#  'commercially.',
#  'prohibited',
#  'commercial',
#  'distribution',
#  'includes',
#  'by',
#  'any',
#  'service',
#  'that',
#  'charges',
#  'for',
#  'download',
#  'time',
#  'or',
#  'for',
#  'membership.>>',
#  '*project',
#  'gutenberg',
#  'is',
#  'proud',
#  'to',
#  'cooperate',
#  'with',
#  'the',
#  'world',
#  'library*',
#  'in',
#  'the',
#  'presentation',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'for',
#  'your',
#  'reading',
#  'for',
#  'education',
#  'and',
#  'entertainment.',
#  'however,',
#  'this',
#  'is',
#  'neither',
#  'shareware',
#  'nor',
#  'public',
#  'domain.',
#  '.',
#  '.and',
#  'under',
#  'the',
#  'library',
#  'of',
#  'the',
#  'future',
#  'conditions',
#  'of',
#  'this',
#  'presentation.',
#  '.',
#  '.no',
#  'charges',
#  'may',
#  'be',
#  'made',
#  'for',
#  '*any*',
#  'access',
#  'to',
#  'this',
#  'material.',
#  'you',
#  'are',
#  'encouraged!!',
#  'to',
#  'give',
#  'it',
#  'away',
#  'to',
#  'anyone',
#  'you',
#  'like,',
#  'but',
#  'no',
#  'charges',
#  'are',
#  'allowed!!',
#  '*****',
#  'small',
#  'print!',
#  'for',
#  'complete',
#  'shakespeare',
#  '*****',
#  'this',
#  'electronic',
#  'version',
#  'of',
#  'the',
#  'complete',
#  'works',
#  'of',
#  'william',
#  'shakespeare',
#  'is',
#  'copyright',
#  '1990-1993',
#  'by',
#  'world',
#  'library,',
#  'inc.,',
#  'and',
#  'is',
#  'provided',
#  'by',
#  'project',
#  'gutenberg',
#  'etext',
#  'of',
#  'illinois',
#  'benedictine',
#  'college',
#  'with',
#  'permission.',
#  'since',
#  'unlike',
#  'many',
#  'other',
#  'project',
#  'gutenberg-tm',
#  'etexts,',
#  'this',
#  'etext',
#  'is',
#  'copyright',
#  'protected,',
#  'and',
#  'since',
#  'the',
#  'materials',
#  'and',
#  'methods',
#  'you',
#  'use',
#  'will',
#  'effect',
#  'the',
#  "project's",
#  'reputation,',
#  'your',
#  'right',
#  'to',
#  'copy',
#  'and',
#  'distribute',
#  'it',
#  'is',
#  'limited',
#  'by',
#  'the',
#  'copyright',
#  'and',
#  'other',
#  'laws,',
#  'and',
#  'by',
#  'the',
#  'conditions',
#  'of',
#  'this',
#  '"small',
#  'print!"',
#  'statement.',
#  '1.',
#  'license',
#  'a)',
#  'you',
#  'may',
#  '(and',
#  'are',
#  'encouraged)',
#  'to',
#  'distribute',
#  'electronic',
#  'and',
#  'machine',
#  'readable',
#  'copies',
#  'of',
#  'this',
#  'etext,',
#  'so',
#  'long',
#  'as',
#  'such',
#  'copies',
#  '(1)',
#  'are',
#  'for',
#  'your',
#  'or',
#  'others',
#  'personal',
#  'use',
#  'only,',
#  'and',
#  '(2)',
#  'are',
#  'not',
#  'distributed',
#  'or',
#  'used',
#  'commercially.',
#  'prohibited',
#  'commercial',
#  'distribution',
#  'includes',
#  'by',
#  'any',
#  'service',
#  'that',
#  'charges',
#  'for',
#  'download',
#  'time',
#  'or',
#  'for',
#  'membership.',
#  'b)',
#  'this',
#  'license',
#  'is',
#  'subject',
#  'to',
#  'the',
#  'conditions',
#  'that',
#  'you',
#  'honor',
#  'the',
#  'refund',
#  'and',
#  'replacement',
#  'provisions',
#  'of',
#  'this',
#  '"small',
#  'print!"',
#  'statement;',
#  'and',
#  'that',
#  'you',
#  'distribute',
#  'exact',
#  'copies',
#  'of',
#  'this',
#  'etext,',
#  'including',
#  'this',
#  'small',
#  'print',
#  'statement.',
#  'such',
#  'copies',
#  'can',
#  'be',
#  'compressed',
#  'or',
#  'any',
#  'proprietary',
#  'form',
#  '(including',
#  'any',
#  'form',
#  'resulting',
#  'from',
#  'word',
#  'processing',
#  'or',
#  'hypertext',
#  'software),',
#  'so',
#  'long',
#  'as',
#  '*either*:',
#  '(1)',
#  'the',
#  'etext,',
#  'when',
#  'displayed,',
#  'is',
#  'clearly',
#  'readable,',
#  'and',
#  'does',
#  '*not*',
#  'contain',
#  'characters',
#  'other',
#  'than',
#  'those',
#  'intended',
#  'by',
#  'the',
#  'author',
#  'of',
#  'the',
#  'work,',
#  'although',
#  'tilde',
#  '(~),',
#  'asterisk',
#  '(*)',
#  'and',
#  'underline',
#  '(_)',
#  'characters',
#  'may',
#  'be',
#  'used',
#  'to',
#  'convey',
#  'punctuation',
#  'intended',
#  'by',
#  'the',
#  'author,',
#  'and',
#  'additional',
#  'characters',
#  'may',
#  'be',
#  'used',
#  'to',
#  'indicate',
#  'hypertext',
#  'links;',
#  'or',
#  '(2)',
#  'the',
#  'etext',
#  'is',
#  'readily',
#  'convertible',
#  'by',
#  'the',
#  'reader',
#  'at',
#  'no',
#  'expense',
#  'into',
#  'plain',
#  'ascii,',
#  'ebcdic',
#  'or',
#  'equivalent',
#  'form',
#  'by',
#  'the',
#  'program',
#  'that',
#  'displays',
#  'the',
#  'etext',
#  '(as',
#  'is',
#  'the',
#  'case,',
#  'for',
#  'instance,',
#  'with',
#  'most',
#  'word',
#  'processors);',
#  'or',
#  '(3)',
#  'you',
#  'provide',
#  'or',
#  'agree',
#  'to',
#  'provide',
#  'on',
#  'request',
#  'at',
#  'no',
#  'additional',
#  'cost,',
#  'fee',
#  'or',
#  'expense,',
#  'a',
#  'copy',
#  'of',
#  'the',
#  'etext',
#  'in',
#  'plain',
#  'ascii.',
#  '2.',
#  'limited',
#  'warranty;',
#  'disclaimer',
#  'of',
#  'damages',
#  'this',
#  'etext',
#  'may',
#  'contain',
#  'a',
#  '"defect"',
#  'in',
#  'the',
#  'form',
#  'of',
#  'incomplete,',
#  'inaccurate',
#  'or',
#  'corrupt',
#  'data,',
#  'transcription',
#  'errors,',
#  'a',
#  'copyright',
#  'or',
#  'other',
#  'infringement,',
#  'a',
#  'defective',
#  'or',
#  'damaged',
#  'disk,',
#  'computer',
#  'virus,',
#  'or',
#  'codes',
#  'that',
#  'damage',
#  'or',
#  'cannot',
#  'be',
#  'read',
#  'by',
#  'your',
#  'equipment.',
#  'but',
#  'for',
#  'the',
#  '"right',
#  'of',
#  'replacement',
#  'or',
#  'refund"',
#  'described',
#  'below,',
#  'the',
#  'project',
#  '(and',
#  'any',
#  'other',
#  'party',
#  'you',
#  'may',
#  'receive',
#  'this',
#  'etext',
#  'from',
#  'as',
#  'a',
#  'project',
#  'gutenberg-tm',
#  'etext)',
#  'disclaims',
#  'all',
#  'liability',
#  'to',
#  'you',
#  'for',
#  'damages,',
#  'costs',
#  'and',
#  'expenses,',
#  'including',
#  'legal',
#  'fees,',
#  'and',
#  'you',
#  'have',
#  'no',
#  'remedies',
#  'for',
#  'negligence',
#  'or',
#  'under',
#  'strict',
#  'liability,',
#  'or',
#  'for',
#  'breach',
#  'of',
#  'warranty',
#  'or',
#  'contract,',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'indirect,',
#  'consequential,',
#  'punitive',
#  'or',
#  'incidental',
#  'damages,',
#  'even',
#  'if',
#  'you',
#  'give',
#  'notice',
#  'of',
#  'the',
#  'possibility',
#  'of',
#  'such',
#  'damages.',
#  'if',
#  'you',
#  'discover',
#  'a',
#  'defect',
#  'in',
#  'this',
#  'etext',
#  'within',
#  '90',
#  'days',
#  'of',
#  'receiv-',
#  'ing',
#  'it,',
#  'you',
#  'can',
#  'receive',
#  'a',
#  'refund',
#  'of',
#  'the',
#  'money',
#  '(if',
#  'any)',
#  'you',
#  'paid',
#  'for',
#  'it',
#  'by',
#  'sending',
#  'an',
#  'explanatory',
#  'note',
#  'within',
#  'that',
#  'time',
#  'to',
#  'the',
#  'person',
#  'you',
#  'received',
#  'it',
#  'from.',
#  'if',
#  'you',
#  'received',
#  'it',
#  'on',
#  'a',
#  'physical',
#  'medium,',
#  'you',
#  'must',
#  'return',
#  'it',
#  'with',
#  'your',
#  'note,',
#  'and',
#  'such',
#  'person',
#  'may',
#  'choose',
#  'to',
#  'alternatively',
#  'give',
#  'you',
#  'a',
#  'replacement',
#  'copy.',
#  'if',
#  'you',
#  'received',
#  'it',
#  'electronically,',
#  'such',
#  'person',
#  'may',
#  'choose',
#  'to',
#  'alternatively',
#  'give',
#  'you',
#  'a',
#  'second',
#  'opportunity',
#  'to',
#  'receive',
#  'it',
#  'electronically.',
#  'this',
#  'etext',
#  'is',
#  'otherwise',
#  'provided',
#  'to',
#  'you',
#  '"as-is".',
#  'no',
#  'other',
#  'warranties',
#  'of',
#  'any',
#  'kind,',
#  'express',
#  'or',
#  'implied,',
#  'are',
#  'made',
#  'to',
#  'you',
#  'as',
#  'to',
#  'the',
#  'etext',
#  'or',
#  'any',
#  'medium',
#  'it',
#  'may',
#  'be',
#  'on,',
#  'including',
#  'but',
#  'not',
#  'limited',
#  'to',
#  'warranties',
#  'of',
#  'merchantability',
#  'or',
#  'fitness',
#  'for',
#  'a',
#  'particular',
#  'purpose.',
#  'some',
#  'states',
#  'do',
#  'not',
#  'allow',
#  'disclaimers',
#  'of',
#  'implied',
#  'warranties',
#  'or',
#  'the',
#  'exclusion',
#  'or',
#  'limitation',
#  'of',
#  'consequen-',
#  'tial',
#  'damages,',
#  'so',
#  'the',
#  'above',
#  'disclaimers',
#  'and',
#  'exclusions',
#  'may',
#  'not',
#  'apply',
#  'to',
#  'you,',
#  'and',
#  'you',
#  'may',
#  'have',
#  'other',
#  'legal',
#  'rights.',
#  '3.',
#  'indemnity:',
#  'you',
#  'will',
#  'indemnify',
#  'and',
#  'hold',
#  'the',
#  'project,',
#  'its',
#  'directors,',
#  'officers,',
#  'members',
#  'and',
#  'agents',
#  'harmless',
#  'from',
#  'all',
#  'lia-',
#  'bility,',
#  'cost',
#  'and',
#  'expense,',
#  'including',
#  'legal',
#  'fees,',
#  'that',
#  'arise',
#  'directly',
#  'or',
#  'indirectly',
#  'from',
#  'any',
#  'of',
#  'the',
#  'following',
#  'that',
#  'you',
#  'do',
#  'or',
#  'cause:',
#  '[a]',
#  'distribution',
#  'of',
#  'this',
#  'etext,',
#  '[b]',
#  'alteration,',
#  'modification,',
#  'or',
#  'addition',
#  'to',
#  'the',
#  'etext,',
#  'or',
#  '[c]',
#  'any',
#  'defect.',
#  '4.',
#  'what',
#  'if',
#  'you',
#  '*want*',
#  'to',
#  ...]

# %% [markdown]
# <h3> What is the answer to this </h3>

# %%
max(words_shakespeare_list)
# Out:
# '}'

# %% [markdown]
# <pre>
# Why.............. ??
# </pre>

# %%
#lets see this - it will see alphabetical order
max(['dylan','dustin','amanda','becca','joseph','aidan'])
# Out:
# 'joseph'

# %%
#why becca in small letters in the end 
sorted(['Dylan','Dustin','Becca','becca'])
# Out:
# ['Becca', 'Dustin', 'Dylan', 'becca']

# %% [markdown]
# <h3> That was because of the ascii code - Comparision is made on ASCII </h3>

# %%
help(ord) #returns string
# Out:
# Help on built-in function ord in module __builtin__:
#
# ord(...)
#     ord(c) -> integer
#
#     Return the integer ordinal of a one-character string.

# %%
#ascii code of 'b'
ord('b')
# Out:
# 98

# %%
#ascii code of 'B'
ord('B')
# Out:
# 66

# %%
max('b','B')
# Out:
# 'b'

# %% [markdown]
# <pre>
# So which one is bigger - 'b'
# </pre>

# %%
#for shakespeare it was }
ord('}')
# Out:
# 125

# %% [markdown]
# <pre>
# It was above any character in alphabetic sequence and that is why
# </pre>

# %%
sorted(['vijendra','Vijendra','{vijendra}','z'])
# Out:
# ['Vijendra', 'vijendra', 'z', '{vijendra}']

# %%
print ord('{')
print ord('z')
# Out:
# 123
# 122

# %% [markdown]
# <h3>Now the longest word </h3>

# %%
#this is certaily not written by Shakespeare but there in txt file
#but this is the largest
max(words_shakespeare_list,key = len)
# Out:
# 'http://www.ibiblio.org/gutenberg/etext06'

# %%
#get the longest 25
sorted(words_shakespeare_list,key = len)[-25:]
# Out:
# ['senseless-obstinate,',
#  '(www.gutenberg.org),',
#  "that-way-accomplish'd",
#  'candle-wasters--bring',
#  '(trademark/copyright)',
#  'http://www.pglaf.org.',
#  'to-and-fro-conflicting',
#  "obligation-'armigero.'",
#  'castalion-king-urinal.',
#  "richard!'-'god-a-mercy,",
#  'water-flies-diminutives',
#  'http://pglaf.org/donate',
#  'king_henry_viii|epilogue',
#  'http://www.gutenberg.org',
#  "six-or-seven-times-honour'd",
#  '(72600.2026@compuserve.com);',
#  'honorificabilitudinitatibus;',
#  'http://pglaf.org/fundraising.',
#  'http://www.gutenberg.org/1/0/100/',
#  'http://www.gutenberg.org/license).',
#  'tragical-comical-historical-pastoral;',
#  'http://www.gutenberg.org/gutindex.all',
#  'http://www.gutenberg.org/1/0/2/3/10234',
#  'http://www.gutenberg.org/2/4/6/8/24689',
#  'http://www.ibiblio.org/gutenberg/etext06']

# %%
#same thing as above
#reverse is true this time descending order
sorted(words_shakespeare_list,key = len,reverse = True)[:25]
# Out:
# ['http://www.ibiblio.org/gutenberg/etext06',
#  'http://www.gutenberg.org/1/0/2/3/10234',
#  'http://www.gutenberg.org/2/4/6/8/24689',
#  'tragical-comical-historical-pastoral;',
#  'http://www.gutenberg.org/gutindex.all',
#  'http://www.gutenberg.org/license).',
#  'http://www.gutenberg.org/1/0/100/',
#  'http://pglaf.org/fundraising.',
#  '(72600.2026@compuserve.com);',
#  'honorificabilitudinitatibus;',
#  "six-or-seven-times-honour'd",
#  'king_henry_viii|epilogue',
#  'http://www.gutenberg.org',
#  "richard!'-'god-a-mercy,",
#  'water-flies-diminutives',
#  'http://pglaf.org/donate',
#  'to-and-fro-conflicting',
#  "obligation-'armigero.'",
#  'castalion-king-urinal.',
#  "that-way-accomplish'd",
#  'candle-wasters--bring',
#  '(trademark/copyright)',
#  'http://www.pglaf.org.',
#  'shameless-desperate,',
#  'historical-pastoral,']
